# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv("meteo_data.csv")
df
# Out:
#        SOLAR_RADIATION  PRECIPITATION  WIND_SPEED  LEAF_WETNESS  \
# 0                276.0            0.0         1.5           0.0
# 1                178.0            0.0         1.1           0.0
# 2                130.0            0.0         1.5           0.0
# 3                 42.0            0.0         1.7           0.0
# 4                  0.0            0.0         1.0           0.0
# ...                ...            ...         ...           ...
# 13158            115.0            0.0         0.4           0.0
# 13159            287.0            0.0         1.7           0.0
# 13160            407.0            0.0         2.0           0.0
# 13161            195.0            0.0         1.3           0.0
# 13162            225.0            0.0         1.4           0.0
#
#        HC_AIR_TEMPERATURE  HC_RELATIVE_HUMIDITY  DEW_POINT
# 0                   19.32                 47.16        7.5
# 1                   19.61                 45.84        7.4
# 2                   19.47                 44.81        6.9
# 3                   18.93                 45.42        6.7
# 4                   18.40                 47.91        6.9
# ...                   ...                   ...        ...
# 13158                2.13                  0.00        0.0
# 13159                2.95                  0.00        0.0
# 13160                4.15                  0.00        0.0
# 13161                3.84                  0.00        0.0
# 13162                3.88                  8.33        0.0
#
# [13163 rows x 7 columns]

# %%
temp = df['HC_AIR_TEMPERATURE']

# Создание массива индексов для оси X
indices = np.arange(len(temp))

plt.figure(figsize=(10, 6))
plt.plot(indices, temp, label='Температура воздуха', color='blue')

# Настройка графика
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# [[[1], [2], [3], [4], [5]]] [6]
# [[[2], [3], [4], [5], [6]]] [7]
# [[[3], [4], [5], [6], [7]]] [8]

def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
X1.shape, y1.shape
# Out:
# ((13158, 5, 1), (13158,))

# %%
X_train1, y_train1 = X1[:10000], y1[:10000]
X_val1, y_val1 = X1[10000:11500], y1[10000:11500]
X_test1, y_test1 = X1[11500:], y1[11500:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((10000, 5, 1), (10000,), (1500, 5, 1), (1500,), (1658, 5, 1), (1658,))

# %%
model2 = Sequential()
model2.add(InputLayer((5, 1)))
model2.add(Conv1D(64, kernel_size=2, activation='relu'))
model2.add(Flatten())
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))
model2.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_4 (Conv1D)                    │ (None, 4, 64)               │             192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 8)                   │           2,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,257 (8.82 KB)
#  Trainable params: 2,257 (8.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp2 = ModelCheckpoint('model2/model2.keras', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp2])
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 117.9841 - root_mean_squared_error: 10.7635 - val_loss: 5.6577 - val_root_mean_squared_error: 2.3802
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.1795 - root_mean_squared_error: 3.1829 - val_loss: 3.4796 - val_root_mean_squared_error: 1.8660
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.2607 - root_mean_squared_error: 2.5011 - val_loss: 2.4549 - val_root_mean_squared_error: 1.5671
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3549 - root_mean_squared_error: 2.0863 - val_loss: 1.9320 - val_root_mean_squared_error: 1.3901
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.2708 - root_mean_squared_error: 1.8081 - val_loss: 1.5889 - val_root_mean_squared_error: 1.2605
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.4914 - root_mean_squared_error: 1.5781 - val_loss: 1.4289 - val_root_mean_squared_error: 1.1953
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2890 - root_mean_squared_error: 1.5075 - val_loss: 1.2235 - val_root_mean_squared_error: 1.1060
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.9461 - root_mean_squared_error: 1.3943 - val_loss: 1.1057 - val_root_mean_squared_error: 1.0514
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.6928 - root_mean_squared_error: 1.3005 - val_loss: 1.0703 - val_root_mean_squared_error: 1.0344
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4383 - root_mean_squared_error: 1.1987 - val_loss: 0.9757 - val_root_mean_squared_error: 0.9876

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model2.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[1300:1500], label='Предсказанные значения', color='blue')
plt.plot(y_test1[1300:1500], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Вычисление коэффициента детерминации
r2 = r2_score(y_test1, y_pred1)
print('R^2 Score on Test Set:', r2)
# Out:
# R^2 Score on Test Set: 0.9715562990245215
