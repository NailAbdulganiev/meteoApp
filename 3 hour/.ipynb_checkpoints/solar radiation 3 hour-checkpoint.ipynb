# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_csv("meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

required_cols = ['SOLAR_RADIATION']
df = df[required_cols]
df
# Out:
#                      SOLAR_RADIATION
# DATE
# 2022-10-26 22:00:00              0.0
# 2022-10-26 23:00:00              0.0
# 2022-10-27 00:00:00              0.0
# 2022-10-27 01:00:00              0.0
# 2022-10-27 02:00:00              0.0
# ...                              ...
# 2024-05-22 17:00:00            447.0
# 2024-05-22 18:00:00            266.0
# 2024-05-22 19:00:00             99.0
# 2024-05-22 20:00:00             10.0
# 2024-05-22 21:00:00              0.0
#
# [13763 rows x 1 columns]

# %%
temp = df['SOLAR_RADIATION']

plt.figure(figsize=(10, 6))
plt.plot(df['SOLAR_RADIATION'], label='Солнечная радиация', color='blue')

# Настройка графика
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# предсказание, основанное не предыдущем суточном дне
def df_to_X_y(df, window_size=24):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 24
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
print(X1.shape, y1.shape)
# Out:
# (13739, 24, 1) (13739,)

# %%
X_train1, y_train1 = X1[:10500], y1[:10500]
X_val1, y_val1 = X1[10500:11800], y1[10500:11800]
X_test1, y_test1 = X1[11800:], y1[11800:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((10500, 24, 1), (10500,), (1300, 24, 1), (1300,), (1939, 24, 1), (1939,))

# %%
# Создание и компиляция модели
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, 1)))  # Правильный входной слой
model2.add(Conv1D(64, kernel_size=2, activation='relu'))
model2.add(Flatten())
model2.add(Dense(8, activation='relu'))
model2.add(Dense(1, activation='relu'))  # Используем ReLU для выхода
model2.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_5 (Conv1D)                    │ (None, 23, 64)              │             192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 1472)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 8)                   │          11,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,985 (46.82 KB)
#  Trainable params: 11,985 (46.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Настройки обратного вызова и компиляции модели
cp2 = ModelCheckpoint('model2/model2-solar-radiation.keras', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
# Обучение модели
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27263.4902 - root_mean_squared_error: 162.0705 - val_loss: 3240.8259 - val_root_mean_squared_error: 56.8604
# Epoch 2/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5556.0068 - root_mean_squared_error: 74.4853 - val_loss: 2035.6715 - val_root_mean_squared_error: 44.9951
# Epoch 3/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4155.3721 - root_mean_squared_error: 64.4465 - val_loss: 1592.7517 - val_root_mean_squared_error: 39.7529
# Epoch 4/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3422.6643 - root_mean_squared_error: 58.4512 - val_loss: 1338.9055 - val_root_mean_squared_error: 36.4510
# Epoch 5/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3081.4307 - root_mean_squared_error: 55.4788 - val_loss: 1207.8892 - val_root_mean_squared_error: 34.6308
# Epoch 6/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2672.3918 - root_mean_squared_error: 51.6300 - val_loss: 1173.2229 - val_root_mean_squared_error: 34.1185
# Epoch 7/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2802.6731 - root_mean_squared_error: 52.9031 - val_loss: 1102.7487 - val_root_mean_squared_error: 33.0720
# Epoch 8/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2656.1841 - root_mean_squared_error: 51.5011 - val_loss: 1041.1851 - val_root_mean_squared_error: 32.1311
# Epoch 9/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2682.3188 - root_mean_squared_error: 51.7588 - val_loss: 1015.5748 - val_root_mean_squared_error: 31.7312
# Epoch 10/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2784.7217 - root_mean_squared_error: 52.6129 - val_loss: 1028.7003 - val_root_mean_squared_error: 31.9418
# Epoch 11/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2588.3909 - root_mean_squared_error: 50.8254 - val_loss: 1019.0143 - val_root_mean_squared_error: 31.7685
# Epoch 12/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2697.0857 - root_mean_squared_error: 51.9117 - val_loss: 985.8610 - val_root_mean_squared_error: 31.2662
# Epoch 13/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2676.1738 - root_mean_squared_error: 51.6993 - val_loss: 998.4370 - val_root_mean_squared_error: 31.4392
# Epoch 14/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2615.6938 - root_mean_squared_error: 51.1181 - val_loss: 986.5939 - val_root_mean_squared_error: 31.2489
# Epoch 15/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2776.2402 - root_mean_squared_error: 52.6745 - val_loss: 992.5214 - val_root_mean_squared_error: 31.3420
# Epoch 16/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2644.5781 - root_mean_squared_error: 51.4092 - val_loss: 983.5363 - val_root_mean_squared_error: 31.1938
# Epoch 17/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2643.8755 - root_mean_squared_error: 51.3919 - val_loss: 974.8488 - val_root_mean_squared_error: 31.0746
# Epoch 18/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2501.2039 - root_mean_squared_error: 49.9873 - val_loss: 987.9952 - val_root_mean_squared_error: 31.3059
# Epoch 19/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2520.8101 - root_mean_squared_error: 50.1277 - val_loss: 1016.1335 - val_root_mean_squared_error: 31.7201
# Epoch 20/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2603.3699 - root_mean_squared_error: 51.0010 - val_loss: 967.0966 - val_root_mean_squared_error: 30.9597
# Epoch 21/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2441.4590 - root_mean_squared_error: 49.3889 - val_loss: 964.4017 - val_root_mean_squared_error: 30.9034
# Epoch 22/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2438.5525 - root_mean_squared_error: 49.3106 - val_loss: 979.7063 - val_root_mean_squared_error: 31.1444
# Epoch 23/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2496.1309 - root_mean_squared_error: 49.8996 - val_loss: 944.3077 - val_root_mean_squared_error: 30.5816
# Epoch 24/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2719.7947 - root_mean_squared_error: 52.1295 - val_loss: 951.9009 - val_root_mean_squared_error: 30.7036
# Epoch 25/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2577.4753 - root_mean_squared_error: 50.7450 - val_loss: 961.4382 - val_root_mean_squared_error: 30.8519
# Epoch 26/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2473.7573 - root_mean_squared_error: 49.4962 - val_loss: 945.6975 - val_root_mean_squared_error: 30.5973
# Epoch 27/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2592.4302 - root_mean_squared_error: 50.8820 - val_loss: 926.4329 - val_root_mean_squared_error: 30.2962
# Epoch 28/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2369.7019 - root_mean_squared_error: 48.5821 - val_loss: 936.8495 - val_root_mean_squared_error: 30.4441
# Epoch 29/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2616.8887 - root_mean_squared_error: 51.0978 - val_loss: 956.7773 - val_root_mean_squared_error: 30.7782
# Epoch 30/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2628.6289 - root_mean_squared_error: 51.2508 - val_loss: 971.0105 - val_root_mean_squared_error: 31.0235
# Epoch 31/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2553.7295 - root_mean_squared_error: 50.5239 - val_loss: 906.0503 - val_root_mean_squared_error: 29.9554
# Epoch 32/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2714.2505 - root_mean_squared_error: 51.9778 - val_loss: 937.1741 - val_root_mean_squared_error: 30.4723
# Epoch 33/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2694.6863 - root_mean_squared_error: 51.8688 - val_loss: 968.5392 - val_root_mean_squared_error: 31.0040
# Epoch 34/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2512.8611 - root_mean_squared_error: 50.0900 - val_loss: 933.9314 - val_root_mean_squared_error: 30.4177
# Epoch 35/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2532.8811 - root_mean_squared_error: 50.2522 - val_loss: 917.2028 - val_root_mean_squared_error: 30.1424
# Epoch 36/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2607.9939 - root_mean_squared_error: 51.0392 - val_loss: 910.9006 - val_root_mean_squared_error: 30.0510
# Epoch 37/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2575.2705 - root_mean_squared_error: 50.7058 - val_loss: 913.2543 - val_root_mean_squared_error: 30.0877
# Epoch 38/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2465.6223 - root_mean_squared_error: 49.6087 - val_loss: 907.5526 - val_root_mean_squared_error: 29.9788
# Epoch 39/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2471.2273 - root_mean_squared_error: 49.6826 - val_loss: 939.2646 - val_root_mean_squared_error: 30.5183
# Epoch 40/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2405.2290 - root_mean_squared_error: 49.0277 - val_loss: 897.5982 - val_root_mean_squared_error: 29.8172
# Epoch 41/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2495.0054 - root_mean_squared_error: 49.9320 - val_loss: 903.4292 - val_root_mean_squared_error: 29.9283
# Epoch 42/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2603.4124 - root_mean_squared_error: 50.9846 - val_loss: 894.8806 - val_root_mean_squared_error: 29.7911
# Epoch 43/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2415.2295 - root_mean_squared_error: 49.1052 - val_loss: 921.0078 - val_root_mean_squared_error: 30.2181
# Epoch 44/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2630.0259 - root_mean_squared_error: 51.2138 - val_loss: 917.7068 - val_root_mean_squared_error: 30.1696
# Epoch 45/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2293.6831 - root_mean_squared_error: 47.8387 - val_loss: 914.9529 - val_root_mean_squared_error: 30.1320
# Epoch 46/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2722.3032 - root_mean_squared_error: 52.0462 - val_loss: 905.0483 - val_root_mean_squared_error: 29.9533
# Epoch 47/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2359.9385 - root_mean_squared_error: 48.5565 - val_loss: 923.6928 - val_root_mean_squared_error: 30.2617
# Epoch 48/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2593.0586 - root_mean_squared_error: 50.8601 - val_loss: 915.8001 - val_root_mean_squared_error: 30.1305
# Epoch 49/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2441.2939 - root_mean_squared_error: 49.3817 - val_loss: 910.3448 - val_root_mean_squared_error: 30.0424
# Epoch 50/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2522.8110 - root_mean_squared_error: 50.2144 - val_loss: 949.3331 - val_root_mean_squared_error: 30.6692

# %%
# Прогнозирование на тестовых данных
y_pred = model2.predict(X_test1)

# Вывод предсказаний
print(y_pred)
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[  0.     ]
#  [  0.     ]
#  [  0.     ]
#  ...
#  [137.9707 ]
#  [ 17.95284]
#  [  0.     ]]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=10):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='H')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, 1)
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append(prediction[0, 0])
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = temp.values[-WINDOW_SIZE:]
last_known_dates = temp.index[-WINDOW_SIZE:]

# Прогнозирование на 3 шага вперед
future_steps = 3
future_dates, predictions = predict_future(model2, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# C:\Users\Счастливый Наиль\AppData\Local\Temp\ipykernel_18088\2592788942.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='H')[1:]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-05-22 22:00:00: 0.0
# 2024-05-22 23:00:00: 0.0
# 2024-05-23 00:00:00: 0.0

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model2.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[700:748], label='Предсказанные значения', color='blue')
plt.plot(y_test1[700:748], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Оценка MAE
mae = mean_absolute_error(y_test1, y_pred1)

# Оценка MSE
mse = mean_squared_error(y_test1, y_pred1)

# Оценка RMSE
rmse = np.sqrt(mse)

# Оценка R^2
r2 = r2_score(y_test1, y_pred1)

print("Средняя абсолютная ошибка (MAE):", mae)
print("Средняя квадратичная ошибка (MSE):", mse)
print("Корень из среднеквадратичной ошибки (RMSE):", rmse)
print("Коэффициент детерминации (R^2):", r2)
# Out:
# Средняя абсолютная ошибка (MAE): 31.827683330531308
# Средняя квадратичная ошибка (MSE): 4030.6754044893296
# Корень из среднеквадратичной ошибки (RMSE): 63.487600399521554
# Коэффициент детерминации (R^2): 0.935202633769513
