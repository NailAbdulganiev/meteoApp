# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

df = pd.read_csv("../meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

required_cols = ['LEAF_WETNESS']
df = df[required_cols]

temp = df['LEAF_WETNESS']

plt.figure(figsize=(10, 6))
plt.plot(df['LEAF_WETNESS'], label='Влажность листа', color='blue')

# Настройка графика
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# предсказание, основанное не предыдущем суточном дне
def df_to_X_y(df, window_size=5):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE = 5
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
print(X1.shape, y1.shape)

X_train1, y_train1 = X1[:10500], y1[:10500]
X_val1, y_val1 = X1[10500:12000], y1[10500:12000]
X_test1, y_test1 = X1[12000:], y1[12000:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# (13902, 5, 1) (13902,)
# ((10500, 5, 1), (10500,), (1500, 5, 1), (1500,), (1902, 5, 1), (1902,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, 1)))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(32))
model2.add(Dropout(0.5))
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'relu'))
model2.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                        │ (None, 5, 64)               │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 5, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 8)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29,585 (115.57 KB)
#  Trainable params: 29,585 (115.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Настройки обратного вызова и компиляции модели
model_save_path = 'model2/model2-leaf-wetness.keras'
cp2 = ModelCheckpoint(model_save_path, save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
# Обучение модели
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 770.6451 - root_mean_squared_error: 27.7589 - val_loss: 88.1819 - val_root_mean_squared_error: 9.1772
# Epoch 2/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 739.3427 - root_mean_squared_error: 27.1896 - val_loss: 83.6575 - val_root_mean_squared_error: 8.9408
# Epoch 3/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 704.3469 - root_mean_squared_error: 26.5346 - val_loss: 80.9059 - val_root_mean_squared_error: 8.7960
# Epoch 4/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 675.3308 - root_mean_squared_error: 25.9815 - val_loss: 78.1172 - val_root_mean_squared_error: 8.6445
# Epoch 5/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 649.4232 - root_mean_squared_error: 25.4811 - val_loss: 75.2879 - val_root_mean_squared_error: 8.4877
# Epoch 6/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 599.0793 - root_mean_squared_error: 24.4639 - val_loss: 72.1740 - val_root_mean_squared_error: 8.3102
# Epoch 7/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 595.1938 - root_mean_squared_error: 24.3839 - val_loss: 69.2055 - val_root_mean_squared_error: 8.1378
# Epoch 8/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 570.9380 - root_mean_squared_error: 23.8890 - val_loss: 65.7179 - val_root_mean_squared_error: 7.9306
# Epoch 9/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 526.5122 - root_mean_squared_error: 22.9423 - val_loss: 60.1325 - val_root_mean_squared_error: 7.5880
# Epoch 10/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 465.6931 - root_mean_squared_error: 21.5789 - val_loss: 54.2720 - val_root_mean_squared_error: 7.2098
# Epoch 11/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 413.0278 - root_mean_squared_error: 20.3161 - val_loss: 48.8983 - val_root_mean_squared_error: 6.8448
# Epoch 12/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 369.3315 - root_mean_squared_error: 19.2146 - val_loss: 44.0332 - val_root_mean_squared_error: 6.4980
# Epoch 13/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 332.4099 - root_mean_squared_error: 18.2260 - val_loss: 39.7097 - val_root_mean_squared_error: 6.1727
# Epoch 14/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 292.5310 - root_mean_squared_error: 17.1008 - val_loss: 35.9498 - val_root_mean_squared_error: 5.8752
# Epoch 15/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 258.6416 - root_mean_squared_error: 16.0799 - val_loss: 32.9190 - val_root_mean_squared_error: 5.6246
# Epoch 16/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 219.8768 - root_mean_squared_error: 14.8256 - val_loss: 30.4871 - val_root_mean_squared_error: 5.4156
# Epoch 17/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 176.2977 - root_mean_squared_error: 13.2762 - val_loss: 28.7299 - val_root_mean_squared_error: 5.2603
# Epoch 18/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 163.2211 - root_mean_squared_error: 12.7722 - val_loss: 27.0136 - val_root_mean_squared_error: 5.1032
# Epoch 19/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 146.5025 - root_mean_squared_error: 12.0968 - val_loss: 25.6686 - val_root_mean_squared_error: 4.9778
# Epoch 20/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 122.4158 - root_mean_squared_error: 11.0608 - val_loss: 24.0442 - val_root_mean_squared_error: 4.8196
# Epoch 21/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 115.0951 - root_mean_squared_error: 10.7199 - val_loss: 22.4351 - val_root_mean_squared_error: 4.6571
# Epoch 22/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 97.4461 - root_mean_squared_error: 9.8699 - val_loss: 20.1605 - val_root_mean_squared_error: 4.4165
# Epoch 23/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 94.9692 - root_mean_squared_error: 9.7336 - val_loss: 19.0744 - val_root_mean_squared_error: 4.2998
# Epoch 24/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 81.4797 - root_mean_squared_error: 9.0232 - val_loss: 18.1719 - val_root_mean_squared_error: 4.2012
# Epoch 25/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 81.3925 - root_mean_squared_error: 9.0160 - val_loss: 17.6000 - val_root_mean_squared_error: 4.1384
# Epoch 26/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 72.3157 - root_mean_squared_error: 8.4914 - val_loss: 16.7187 - val_root_mean_squared_error: 4.0346
# Epoch 27/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 75.9156 - root_mean_squared_error: 8.7113 - val_loss: 16.2531 - val_root_mean_squared_error: 3.9793
# Epoch 28/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 77.4021 - root_mean_squared_error: 8.7859 - val_loss: 16.5210 - val_root_mean_squared_error: 4.0140
# Epoch 29/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 74.1576 - root_mean_squared_error: 8.5923 - val_loss: 16.2562 - val_root_mean_squared_error: 3.9818
# Epoch 30/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 79.5641 - root_mean_squared_error: 8.9156 - val_loss: 15.8241 - val_root_mean_squared_error: 3.9284
# Epoch 31/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 77.2207 - root_mean_squared_error: 8.7807 - val_loss: 15.5580 - val_root_mean_squared_error: 3.8946
# Epoch 32/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 74.4208 - root_mean_squared_error: 8.6208 - val_loss: 15.2345 - val_root_mean_squared_error: 3.8534
# Epoch 33/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 77.5797 - root_mean_squared_error: 8.8009 - val_loss: 15.7678 - val_root_mean_squared_error: 3.9224
# Epoch 34/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 78.3990 - root_mean_squared_error: 8.8430 - val_loss: 15.4286 - val_root_mean_squared_error: 3.8787
# Epoch 35/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 77.3410 - root_mean_squared_error: 8.7835 - val_loss: 15.4323 - val_root_mean_squared_error: 3.8794
# Epoch 36/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 70.4101 - root_mean_squared_error: 8.3826 - val_loss: 15.6243 - val_root_mean_squared_error: 3.9044
# Epoch 37/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 78.3138 - root_mean_squared_error: 8.8449 - val_loss: 15.5862 - val_root_mean_squared_error: 3.8998
# Epoch 38/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 75.4163 - root_mean_squared_error: 8.6807 - val_loss: 15.2188 - val_root_mean_squared_error: 3.8523
# Epoch 39/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 74.8582 - root_mean_squared_error: 8.6461 - val_loss: 15.4063 - val_root_mean_squared_error: 3.8767
# Epoch 40/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 76.8705 - root_mean_squared_error: 8.7643 - val_loss: 15.1324 - val_root_mean_squared_error: 3.8416
# Epoch 41/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 73.8979 - root_mean_squared_error: 8.5807 - val_loss: 15.2716 - val_root_mean_squared_error: 3.8595
# Epoch 42/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 73.0876 - root_mean_squared_error: 8.5433 - val_loss: 15.3468 - val_root_mean_squared_error: 3.8693
# Epoch 43/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 71.3452 - root_mean_squared_error: 8.4431 - val_loss: 15.4164 - val_root_mean_squared_error: 3.8786
# Epoch 44/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 68.8965 - root_mean_squared_error: 8.2904 - val_loss: 15.2685 - val_root_mean_squared_error: 3.8600
# Epoch 45/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 77.5635 - root_mean_squared_error: 8.7999 - val_loss: 15.2157 - val_root_mean_squared_error: 3.8531
# Epoch 46/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 82.4830 - root_mean_squared_error: 9.0774 - val_loss: 14.9436 - val_root_mean_squared_error: 3.8174
# Epoch 47/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 74.4787 - root_mean_squared_error: 8.6232 - val_loss: 15.1393 - val_root_mean_squared_error: 3.8434
# Epoch 48/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 72.1760 - root_mean_squared_error: 8.4878 - val_loss: 15.0520 - val_root_mean_squared_error: 3.8317
# Epoch 49/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 76.6629 - root_mean_squared_error: 8.7435 - val_loss: 14.8737 - val_root_mean_squared_error: 3.8083
# Epoch 50/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 75.2340 - root_mean_squared_error: 8.6672 - val_loss: 15.1166 - val_root_mean_squared_error: 3.8406

# %%
# Сохранение всей модели на диск
model_save_path = 'model2/model2-leaf-wetness.keras'
model2.save(model_save_path)
print(f"Модель сохранена в {model_save_path}")
# Out:
# Модель сохранена в model2/model2-leaf-wetness.keras

# %%
from keras.models import load_model
model = load_model('model2/model2-leaf-wetness.keras')

# %%
# Прогнозирование на тестовых данных
y_pred = model.predict(X_test1)

# Вывод предсказаний
print(y_pred)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# [[56.76183   ]
#  [ 7.890773  ]
#  [ 3.369474  ]
#  ...
#  [ 0.57390475]
#  [ 0.57390475]
#  [ 0.57390475]]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=5):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='h')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, 1)
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append(prediction[0, 0])
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = temp.values[-WINDOW_SIZE:]
last_known_dates = temp.index[-WINDOW_SIZE:]

# Прогнозирование на 3 шага вперед
future_steps = 3
future_dates, predictions = predict_future(model, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2024-05-25 22:00:00: 0.5739047527313232
# 2024-05-25 23:00:00: 0.595217764377594
# 2024-05-26 00:00:00: 0.6865096092224121

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[700:800], label='Предсказанные значения', color='blue')
plt.plot(y_test1[700:800], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Оценка MAE
mae = mean_absolute_error(y_test1, y_pred1)

# Оценка MSE
mse = mean_squared_error(y_test1, y_pred1)

# Оценка RMSE
rmse = np.sqrt(mse)

# Оценка R^2
r2 = r2_score(y_test1, y_pred1)

print("Средняя абсолютная ошибка (MAE):", mae)
print("Средняя квадратичная ошибка (MSE):", mse)
print("Корень из среднеквадратичной ошибки (RMSE):", rmse)
print("Коэффициент детерминации (R^2):", r2)
# Out:
# Средняя абсолютная ошибка (MAE): 2.184467825823151
# Средняя квадратичная ошибка (MSE): 48.8232527684382
# Корень из среднеквадратичной ошибки (RMSE): 6.987363792478405
# Коэффициент детерминации (R^2): 0.8195219615324045
