# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

df = pd.read_csv("../meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

required_cols = ['WIND_SPEED']
df = df[required_cols]

temp = df['WIND_SPEED']

plt.figure(figsize=(10, 6))
plt.plot(df['WIND_SPEED'], label='Скорость ветра', color='blue')

# Настройка графика
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# предсказание, основанное не предыдущем суточном дне
def df_to_X_y(df, window_size=10):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE = 10
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)

# Размеры выборок
n = len(df)
train_size = int(n * 0.75)
val_size = int(n * 0.125)
test_size = n - train_size - val_size

X_train1, y_train1 = X1[:train_size], y1[:train_size]
X_val1, y_val1 = X1[train_size:train_size + val_size], y1[train_size:train_size + val_size]
X_test1, y_test1 = X1[train_size + val_size:], y1[train_size + val_size:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((39408, 10, 1), (39408,), (6568, 10, 1), (6568,), (6559, 10, 1), (6559,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, 1)))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(32))
model2.add(Dropout(0.5))
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'relu'))
model2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 10, 64)              │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 10, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 8)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29,585 (115.57 KB)
#  Trainable params: 29,585 (115.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Настройки обратного вызова и компиляции модели
model_save_path = 'model2/model2-WIND_SPEED.keras'
cp2 = ModelCheckpoint(model_save_path, save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
# Обучение модели
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 32s 19ms/step - loss: 2.2272 - root_mean_squared_error: 1.4705 - val_loss: 0.5186 - val_root_mean_squared_error: 0.7201
# Epoch 2/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.8356 - root_mean_squared_error: 0.9139 - val_loss: 0.3968 - val_root_mean_squared_error: 0.6300
# Epoch 3/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.6895 - root_mean_squared_error: 0.8302 - val_loss: 0.3383 - val_root_mean_squared_error: 0.5816
# Epoch 4/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.6179 - root_mean_squared_error: 0.7859 - val_loss: 0.3106 - val_root_mean_squared_error: 0.5573
# Epoch 5/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.5727 - root_mean_squared_error: 0.7567 - val_loss: 0.2930 - val_root_mean_squared_error: 0.5413
# Epoch 6/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.5340 - root_mean_squared_error: 0.7307 - val_loss: 0.2859 - val_root_mean_squared_error: 0.5347
# Epoch 7/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.5208 - root_mean_squared_error: 0.7217 - val_loss: 0.2905 - val_root_mean_squared_error: 0.5389
# Epoch 8/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.5188 - root_mean_squared_error: 0.7202 - val_loss: 0.2786 - val_root_mean_squared_error: 0.5279
# Epoch 9/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.5016 - root_mean_squared_error: 0.7081 - val_loss: 0.2804 - val_root_mean_squared_error: 0.5296
# Epoch 10/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 0.4839 - root_mean_squared_error: 0.6956 - val_loss: 0.2733 - val_root_mean_squared_error: 0.5227
# Epoch 11/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.5031 - root_mean_squared_error: 0.7092 - val_loss: 0.2853 - val_root_mean_squared_error: 0.5341
# Epoch 12/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.4896 - root_mean_squared_error: 0.6997 - val_loss: 0.2692 - val_root_mean_squared_error: 0.5189
# Epoch 13/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.4847 - root_mean_squared_error: 0.6962 - val_loss: 0.2728 - val_root_mean_squared_error: 0.5223
# Epoch 14/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.4763 - root_mean_squared_error: 0.6901 - val_loss: 0.2705 - val_root_mean_squared_error: 0.5201
# Epoch 15/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.4597 - root_mean_squared_error: 0.6780 - val_loss: 0.2740 - val_root_mean_squared_error: 0.5235
# Epoch 16/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.4538 - root_mean_squared_error: 0.6736 - val_loss: 0.2747 - val_root_mean_squared_error: 0.5241
# Epoch 17/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 0.4744 - root_mean_squared_error: 0.6879 - val_loss: 0.2678 - val_root_mean_squared_error: 0.5175
# Epoch 18/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.4567 - root_mean_squared_error: 0.6758 - val_loss: 0.2677 - val_root_mean_squared_error: 0.5174
# Epoch 19/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.4428 - root_mean_squared_error: 0.6653 - val_loss: 0.2721 - val_root_mean_squared_error: 0.5217
# Epoch 20/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4550 - root_mean_squared_error: 0.6744 - val_loss: 0.2702 - val_root_mean_squared_error: 0.5198
# Epoch 21/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 0.4440 - root_mean_squared_error: 0.6663 - val_loss: 0.2670 - val_root_mean_squared_error: 0.5168
# Epoch 22/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 0.4495 - root_mean_squared_error: 0.6704 - val_loss: 0.2735 - val_root_mean_squared_error: 0.5230
# Epoch 23/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.4491 - root_mean_squared_error: 0.6701 - val_loss: 0.2759 - val_root_mean_squared_error: 0.5252
# Epoch 24/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.4388 - root_mean_squared_error: 0.6624 - val_loss: 0.2714 - val_root_mean_squared_error: 0.5210
# Epoch 25/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 0.4259 - root_mean_squared_error: 0.6526 - val_loss: 0.2835 - val_root_mean_squared_error: 0.5324
# Epoch 26/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.4492 - root_mean_squared_error: 0.6702 - val_loss: 0.2826 - val_root_mean_squared_error: 0.5316
# Epoch 27/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - loss: 0.4346 - root_mean_squared_error: 0.6592 - val_loss: 0.2695 - val_root_mean_squared_error: 0.5191
# Epoch 28/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.4378 - root_mean_squared_error: 0.6616 - val_loss: 0.2903 - val_root_mean_squared_error: 0.5388
# Epoch 29/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - loss: 0.4209 - root_mean_squared_error: 0.6487 - val_loss: 0.2694 - val_root_mean_squared_error: 0.5191
# Epoch 30/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - loss: 0.4327 - root_mean_squared_error: 0.6578 - val_loss: 0.2715 - val_root_mean_squared_error: 0.5210
# Epoch 31/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.4370 - root_mean_squared_error: 0.6611 - val_loss: 0.2716 - val_root_mean_squared_error: 0.5211
# Epoch 32/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.4270 - root_mean_squared_error: 0.6534 - val_loss: 0.2903 - val_root_mean_squared_error: 0.5388
# Epoch 33/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4413 - root_mean_squared_error: 0.6640 - val_loss: 0.2774 - val_root_mean_squared_error: 0.5267
# Epoch 34/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.4267 - root_mean_squared_error: 0.6532 - val_loss: 0.2750 - val_root_mean_squared_error: 0.5244
# Epoch 35/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.4319 - root_mean_squared_error: 0.6571 - val_loss: 0.2720 - val_root_mean_squared_error: 0.5215
# Epoch 36/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4299 - root_mean_squared_error: 0.6557 - val_loss: 0.2712 - val_root_mean_squared_error: 0.5208
# Epoch 37/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.4259 - root_mean_squared_error: 0.6526 - val_loss: 0.2735 - val_root_mean_squared_error: 0.5230
# Epoch 38/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - loss: 0.4306 - root_mean_squared_error: 0.6561 - val_loss: 0.2704 - val_root_mean_squared_error: 0.5200
# Epoch 39/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - loss: 0.4175 - root_mean_squared_error: 0.6461 - val_loss: 0.2722 - val_root_mean_squared_error: 0.5218
# Epoch 40/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.4405 - root_mean_squared_error: 0.6636 - val_loss: 0.2735 - val_root_mean_squared_error: 0.5229
# Epoch 41/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.4187 - root_mean_squared_error: 0.6470 - val_loss: 0.2723 - val_root_mean_squared_error: 0.5218
# Epoch 42/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.4219 - root_mean_squared_error: 0.6495 - val_loss: 0.2733 - val_root_mean_squared_error: 0.5228
# Epoch 43/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - loss: 0.4234 - root_mean_squared_error: 0.6507 - val_loss: 0.2815 - val_root_mean_squared_error: 0.5306
# Epoch 44/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.4433 - root_mean_squared_error: 0.6655 - val_loss: 0.2713 - val_root_mean_squared_error: 0.5208
# Epoch 45/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.4191 - root_mean_squared_error: 0.6473 - val_loss: 0.2688 - val_root_mean_squared_error: 0.5185
# Epoch 46/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.4293 - root_mean_squared_error: 0.6552 - val_loss: 0.2791 - val_root_mean_squared_error: 0.5283
# Epoch 47/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.4243 - root_mean_squared_error: 0.6514 - val_loss: 0.2789 - val_root_mean_squared_error: 0.5281
# Epoch 48/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.4201 - root_mean_squared_error: 0.6480 - val_loss: 0.2714 - val_root_mean_squared_error: 0.5209
# Epoch 49/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.4235 - root_mean_squared_error: 0.6507 - val_loss: 0.2729 - val_root_mean_squared_error: 0.5224
# Epoch 50/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4136 - root_mean_squared_error: 0.6429 - val_loss: 0.2729 - val_root_mean_squared_error: 0.5224

# %%
# Сохранение всей модели на диск
model_save_path = 'model2/model2-WIND_SPEED.keras'
model2.save(model_save_path)
print(f"Модель сохранена в {model_save_path}")
# Out:
# Модель сохранена в model2/model2-WIND_SPEED.keras

# %%
from keras.models import load_model
model = load_model('model2/model2-WIND_SPEED.keras')

# %%
# Прогнозирование на тестовых данных
y_pred = model.predict(X_test1)

# Вывод предсказаний
print(y_pred)
# Out:
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# [[0.18639627]
#  [0.18580547]
#  [0.18537012]
#  ...
#  [0.8846986 ]
#  [0.62483513]
#  [0.3395258 ]]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=10):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='h')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, 1)
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append(prediction[0, 0])
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = temp.values[-WINDOW_SIZE:]
last_known_dates = temp.index[-WINDOW_SIZE:]

# Прогнозирование на 3 шага вперед
future_steps = 3
future_dates, predictions = predict_future(model, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 2024-06-15 14:00:00: 0.7950383424758911
# 2024-06-15 15:00:00: 0.6758260726928711
# 2024-06-15 16:00:00: 0.5627298951148987

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[700:800], label='Предсказанные значения', color='blue')
plt.plot(y_test1[700:800], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
# Оценка MAE
mae = mean_absolute_error(y_test1, y_pred1)

# Оценка MSE
mse = mean_squared_error(y_test1, y_pred1)

# Оценка RMSE
rmse = np.sqrt(mse)

# Оценка R^2
r2 = r2_score(y_test1, y_pred1)

print("Средняя абсолютная ошибка (MAE):", mae)
print("Средняя квадратичная ошибка (MSE):", mse)
print("Корень из среднеквадратичной ошибки (RMSE):", rmse)
print("Коэффициент детерминации (R^2):", r2)
# Out:
# Средняя абсолютная ошибка (MAE): 0.424936287345674
# Средняя квадратичная ошибка (MSE): 0.3572591188887923
# Корень из среднеквадратичной ошибки (RMSE): 0.5977115683076515
# Коэффициент детерминации (R^2): 0.8764313876241621
