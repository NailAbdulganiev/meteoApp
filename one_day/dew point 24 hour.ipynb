# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

df = pd.read_csv("../meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

required_cols = ['DEW_POINT']
df = df[required_cols]

temp = df['DEW_POINT']

plt.figure(figsize=(10, 6))
plt.plot(df['DEW_POINT'], label='Точка росы', color='blue')

# Настройка графика
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# предсказание, основанное не предыдущем суточном дне
def df_to_X_y(df, window_size=24):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE = 12
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)

# Размеры выборок
n = len(df)
train_size = int(n * 0.75)
val_size = int(n * 0.125)
test_size = n - train_size - val_size

X_train1, y_train1 = X1[:train_size], y1[:train_size]
X_val1, y_val1 = X1[train_size:train_size + val_size], y1[train_size:train_size + val_size]
X_test1, y_test1 = X1[train_size + val_size:], y1[train_size + val_size:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((39408, 12, 1), (39408,), (6568, 12, 1), (6568,), (6557, 12, 1), (6557,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, 1)))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(32))
model2.add(Dropout(0.5))
model2.add(Dense(16, activation='relu'))
model2.add(Dense(8, activation='relu'))
model2.add(Dense(1, activation='relu'))
model2.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                        │ (None, 12, 64)              │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 12, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_7 (LSTM)                        │ (None, 12, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 12, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_8 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 63,009 (246.13 KB)
#  Trainable params: 63,009 (246.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Настройки обратного вызова и компиляции модели
model_save_path = 'model2/model2-DEW_POINT.keras'  
cp2 = ModelCheckpoint(model_save_path, save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
# Обучение модели
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 33s 20ms/step - loss: 15.5724 - root_mean_squared_error: 3.9406 - val_loss: 19.7670 - val_root_mean_squared_error: 4.4460
# Epoch 2/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 7.6377 - root_mean_squared_error: 2.7598 - val_loss: 10.2091 - val_root_mean_squared_error: 3.1952
# Epoch 3/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 5.5391 - root_mean_squared_error: 2.3524 - val_loss: 8.4292 - val_root_mean_squared_error: 2.9033
# Epoch 4/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 5.1413 - root_mean_squared_error: 2.2671 - val_loss: 7.9605 - val_root_mean_squared_error: 2.8214
# Epoch 5/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 5.0490 - root_mean_squared_error: 2.2464 - val_loss: 7.7397 - val_root_mean_squared_error: 2.7820
# Epoch 6/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 4.7368 - root_mean_squared_error: 2.1754 - val_loss: 7.6592 - val_root_mean_squared_error: 2.7675
# Epoch 7/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 4.9089 - root_mean_squared_error: 2.2146 - val_loss: 7.6211 - val_root_mean_squared_error: 2.7606
# Epoch 8/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.8139 - root_mean_squared_error: 2.1930 - val_loss: 7.5450 - val_root_mean_squared_error: 2.7468
# Epoch 9/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.4701 - root_mean_squared_error: 2.1080 - val_loss: 7.4801 - val_root_mean_squared_error: 2.7350
# Epoch 10/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.7794 - root_mean_squared_error: 2.1857 - val_loss: 7.4630 - val_root_mean_squared_error: 2.7319
# Epoch 11/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.4622 - root_mean_squared_error: 2.1109 - val_loss: 7.4350 - val_root_mean_squared_error: 2.7267
# Epoch 12/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 4.9154 - root_mean_squared_error: 2.2156 - val_loss: 7.4682 - val_root_mean_squared_error: 2.7328
# Epoch 13/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 4.6928 - root_mean_squared_error: 2.1643 - val_loss: 7.4883 - val_root_mean_squared_error: 2.7365
# Epoch 14/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 4.8036 - root_mean_squared_error: 2.1898 - val_loss: 7.4378 - val_root_mean_squared_error: 2.7272
# Epoch 15/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 4.7744 - root_mean_squared_error: 2.1838 - val_loss: 7.4285 - val_root_mean_squared_error: 2.7255
# Epoch 16/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.7270 - root_mean_squared_error: 2.1738 - val_loss: 7.4985 - val_root_mean_squared_error: 2.7383
# Epoch 17/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.8707 - root_mean_squared_error: 2.2054 - val_loss: 7.5022 - val_root_mean_squared_error: 2.7390
# Epoch 18/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.6777 - root_mean_squared_error: 2.1612 - val_loss: 7.4267 - val_root_mean_squared_error: 2.7252
# Epoch 19/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.7708 - root_mean_squared_error: 2.1824 - val_loss: 7.4407 - val_root_mean_squared_error: 2.7278
# Epoch 20/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 4.5885 - root_mean_squared_error: 2.1408 - val_loss: 7.4461 - val_root_mean_squared_error: 2.7288
# Epoch 21/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.8741 - root_mean_squared_error: 2.2056 - val_loss: 7.4598 - val_root_mean_squared_error: 2.7313
# Epoch 22/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.7621 - root_mean_squared_error: 2.1808 - val_loss: 7.4705 - val_root_mean_squared_error: 2.7332
# Epoch 23/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.9278 - root_mean_squared_error: 2.2188 - val_loss: 7.3969 - val_root_mean_squared_error: 2.7197
# Epoch 24/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.5948 - root_mean_squared_error: 2.1418 - val_loss: 7.4725 - val_root_mean_squared_error: 2.7336
# Epoch 25/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.5218 - root_mean_squared_error: 2.1252 - val_loss: 7.4128 - val_root_mean_squared_error: 2.7226
# Epoch 26/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.6226 - root_mean_squared_error: 2.1466 - val_loss: 7.4458 - val_root_mean_squared_error: 2.7287
# Epoch 27/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.8347 - root_mean_squared_error: 2.1966 - val_loss: 7.5504 - val_root_mean_squared_error: 2.7478
# Epoch 28/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.7936 - root_mean_squared_error: 2.1872 - val_loss: 7.4997 - val_root_mean_squared_error: 2.7386
# Epoch 29/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.3898 - root_mean_squared_error: 2.0936 - val_loss: 7.4292 - val_root_mean_squared_error: 2.7257
# Epoch 30/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.7640 - root_mean_squared_error: 2.1815 - val_loss: 7.4462 - val_root_mean_squared_error: 2.7288
# Epoch 31/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.2801 - root_mean_squared_error: 2.0665 - val_loss: 7.4670 - val_root_mean_squared_error: 2.7326
# Epoch 32/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.9568 - root_mean_squared_error: 2.2239 - val_loss: 7.5250 - val_root_mean_squared_error: 2.7432
# Epoch 33/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.7831 - root_mean_squared_error: 2.1855 - val_loss: 7.4232 - val_root_mean_squared_error: 2.7245
# Epoch 34/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.8759 - root_mean_squared_error: 2.2065 - val_loss: 7.4322 - val_root_mean_squared_error: 2.7262
# Epoch 35/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.5591 - root_mean_squared_error: 2.1337 - val_loss: 7.4282 - val_root_mean_squared_error: 2.7255
# Epoch 36/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - loss: 4.5481 - root_mean_squared_error: 2.1317 - val_loss: 7.4224 - val_root_mean_squared_error: 2.7244
# Epoch 37/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.3699 - root_mean_squared_error: 2.0885 - val_loss: 7.4546 - val_root_mean_squared_error: 2.7303
# Epoch 38/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - loss: 4.3722 - root_mean_squared_error: 2.0886 - val_loss: 7.4517 - val_root_mean_squared_error: 2.7298
# Epoch 39/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.6583 - root_mean_squared_error: 2.1569 - val_loss: 7.4551 - val_root_mean_squared_error: 2.7304
# Epoch 40/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.4183 - root_mean_squared_error: 2.0994 - val_loss: 7.4588 - val_root_mean_squared_error: 2.7311
# Epoch 41/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.5167 - root_mean_squared_error: 2.1236 - val_loss: 7.4110 - val_root_mean_squared_error: 2.7223
# Epoch 42/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 4.4722 - root_mean_squared_error: 2.1140 - val_loss: 7.4620 - val_root_mean_squared_error: 2.7317
# Epoch 43/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - loss: 4.4823 - root_mean_squared_error: 2.1164 - val_loss: 7.4836 - val_root_mean_squared_error: 2.7356
# Epoch 44/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 4.6170 - root_mean_squared_error: 2.1470 - val_loss: 7.5431 - val_root_mean_squared_error: 2.7465
# Epoch 45/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - loss: 4.4983 - root_mean_squared_error: 2.1200 - val_loss: 7.4816 - val_root_mean_squared_error: 2.7352
# Epoch 46/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 4.5756 - root_mean_squared_error: 2.1373 - val_loss: 7.5058 - val_root_mean_squared_error: 2.7397
# Epoch 47/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - loss: 4.3652 - root_mean_squared_error: 2.0876 - val_loss: 7.5077 - val_root_mean_squared_error: 2.7400
# Epoch 48/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 4.4109 - root_mean_squared_error: 2.0997 - val_loss: 7.7895 - val_root_mean_squared_error: 2.7910
# Epoch 49/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 4.4263 - root_mean_squared_error: 2.1031 - val_loss: 7.5537 - val_root_mean_squared_error: 2.7484
# Epoch 50/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 4.5366 - root_mean_squared_error: 2.1292 - val_loss: 7.5281 - val_root_mean_squared_error: 2.7437

# %%
# Сохранение всей модели на диск
model_save_path = 'model2/model2-DEW_POINT.keras' 
model2.save(model_save_path)
print(f"Модель сохранена в {model_save_path}")
# Out:
# Модель сохранена в model2/model2-DEW_POINT.keras

# %%
from keras.models import load_model
model = load_model('model2/model2-DEW_POINT.keras')

# %%
# Прогнозирование на тестовых данных
y_pred = model.predict(X_test1)

# Вывод предсказаний
print(y_pred)
# Out:
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# [[ 0.      ]
#  [ 0.      ]
#  [ 7.99806 ]
#  ...
#  [17.803516]
#  [17.810081]
#  [18.067644]]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=6):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='h')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, 1)
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append(prediction[0, 0])
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = temp.values[-WINDOW_SIZE:]
last_known_dates = temp.index[-WINDOW_SIZE:]

# Прогнозирование на 3 шага вперед
future_steps = 24
future_dates, predictions = predict_future(model, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-06-15 14:00:00: 16.72433090209961
# 2024-06-15 15:00:00: 15.588519096374512
# 2024-06-15 16:00:00: 14.474555015563965
# 2024-06-15 17:00:00: 13.317208290100098
# 2024-06-15 18:00:00: 12.204115867614746
# 2024-06-15 19:00:00: 11.216778755187988
# 2024-06-15 20:00:00: 10.338974952697754
# 2024-06-15 21:00:00: 9.525793075561523
# 2024-06-15 22:00:00: 8.772828102111816
# 2024-06-15 23:00:00: 8.068758964538574
# 2024-06-16 00:00:00: 7.40350341796875
# 2024-06-16 01:00:00: 6.777070045471191
# 2024-06-16 02:00:00: 6.1920061111450195
# 2024-06-16 03:00:00: 5.668017387390137
# 2024-06-16 04:00:00: 5.2294135093688965
# 2024-06-16 05:00:00: 4.879782676696777
# 2024-06-16 06:00:00: 4.610719680786133
# 2024-06-16 07:00:00: 4.405851364135742
# 2024-06-16 08:00:00: 4.246217250823975
# 2024-06-16 09:00:00: 4.106909275054932
# 2024-06-16 10:00:00: 3.9600629806518555
# 2024-06-16 11:00:00: 3.804811477661133
# 2024-06-16 12:00:00: 3.6367411613464355
# 2024-06-16 13:00:00: 3.45731782913208

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[700:900], label='Предсказанные значения', color='blue')
plt.plot(y_test1[700:900], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
# Оценка MAE
mae = mean_absolute_error(y_test1, y_pred1)

# Оценка MSE
mse = mean_squared_error(y_test1, y_pred1)

# Оценка RMSE
rmse = np.sqrt(mse)

# Оценка R^2
r2 = r2_score(y_test1, y_pred1)

print("Средняя абсолютная ошибка (MAE):", mae)
print("Средняя квадратичная ошибка (MSE):", mse)
print("Корень из среднеквадратичной ошибки (RMSE):", rmse)
print("Коэффициент детерминации (R^2):", r2)
# Out:
# Средняя абсолютная ошибка (MAE): 1.1263200391197015
# Средняя квадратичная ошибка (MSE): 7.618761171275611
# Корень из среднеквадратичной ошибки (RMSE): 2.7602103490994323
# Коэффициент детерминации (R^2): 0.7295493748352855
