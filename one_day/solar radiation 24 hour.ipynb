# %%
# model = Sequential()
# model.add(InputLayer((WINDOW_SIZE, 1)))

# # Первый сверточный слой
# model.add(Conv1D(1024, kernel_size=3, activation='relu'))

# # Второй сверточный слой
# model.add(Conv1D(512, kernel_size=3, activation='relu'))

# # Уменьшение количества нейронов в следующих слоях
# model.add(MaxPooling1D(pool_size=2))
# model.add(BatchNormalization())
# model.add(LSTM(256, return_sequences=True))
# model.add(Dropout(0.5))
# model.add(LSTM(128))
# model.add(Dropout(0.5))

# # Полносвязные слои
# model.add(Dense(128, activation='relu'))
# model.add(Dense(64, activation='relu'))

# # Выходной слой
# model.add(Dense(1, activation='relu'))

# model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 22, 1024)            │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 20, 512)             │       1,573,376 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 10, 512)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 10, 512)             │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 10, 256)             │         787,456 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 10, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 128)                 │         197,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,588,929 (9.88 MB)
#  Trainable params: 2,587,905 (9.87 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
# # Настройки обратного вызова и компиляции модели
# model_save_path = 'model2/model2-solar-radiation.keras'
# cp2 = ModelCheckpoint(model_save_path, save_best_only=True)
# model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# # Сохранение всей модели на диск
# model.save(model_save_path)
# print(f"Модель сохранена в {model_save_path}")
# Out:
# Модель сохранена в model2/model2-solar-radiation.keras

# %%
# # Обучение модели
# model.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 162ms/step - loss: 51618.3633 - root_mean_squared_error: 227.0546 - val_loss: 7505.6675 - val_root_mean_squared_error: 86.2793
# Epoch 2/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 50s 153ms/step - loss: 19737.1465 - root_mean_squared_error: 139.7559 - val_loss: 2062.9727 - val_root_mean_squared_error: 45.4257
# Epoch 3/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 46s 140ms/step - loss: 5663.3535 - root_mean_squared_error: 75.2055 - val_loss: 1391.0649 - val_root_mean_squared_error: 37.3155
# Epoch 4/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 54s 165ms/step - loss: 4190.5464 - root_mean_squared_error: 64.6628 - val_loss: 1038.7742 - val_root_mean_squared_error: 32.2216
# Epoch 5/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 178ms/step - loss: 3619.6765 - root_mean_squared_error: 60.1231 - val_loss: 929.8175 - val_root_mean_squared_error: 30.5000
# Epoch 6/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 58s 176ms/step - loss: 3633.3914 - root_mean_squared_error: 60.2382 - val_loss: 999.1498 - val_root_mean_squared_error: 31.6233
# Epoch 7/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 178ms/step - loss: 3161.0876 - root_mean_squared_error: 56.2060 - val_loss: 847.8859 - val_root_mean_squared_error: 29.1468
# Epoch 8/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 47s 142ms/step - loss: 3193.3618 - root_mean_squared_error: 56.4740 - val_loss: 887.6153 - val_root_mean_squared_error: 29.8091
# Epoch 9/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 51s 154ms/step - loss: 3451.1604 - root_mean_squared_error: 58.6176 - val_loss: 867.0811 - val_root_mean_squared_error: 29.4692
# Epoch 10/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - loss: 3023.5684 - root_mean_squared_error: 54.9047 - val_loss: 878.0442 - val_root_mean_squared_error: 29.6484
# Epoch 11/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 179ms/step - loss: 3105.2969 - root_mean_squared_error: 55.6445 - val_loss: 915.4706 - val_root_mean_squared_error: 30.2570
# Epoch 12/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 179ms/step - loss: 2957.0095 - root_mean_squared_error: 54.3482 - val_loss: 1159.4199 - val_root_mean_squared_error: 34.0087
# Epoch 13/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 61s 186ms/step - loss: 2819.2200 - root_mean_squared_error: 53.0520 - val_loss: 1245.4945 - val_root_mean_squared_error: 35.3115
# Epoch 14/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - loss: 3002.8533 - root_mean_squared_error: 54.7205 - val_loss: 1009.4830 - val_root_mean_squared_error: 31.7694
# Epoch 15/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 178ms/step - loss: 2818.6018 - root_mean_squared_error: 53.0768 - val_loss: 819.0449 - val_root_mean_squared_error: 28.6433
# Epoch 16/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - loss: 2828.2402 - root_mean_squared_error: 53.1570 - val_loss: 885.7648 - val_root_mean_squared_error: 29.7851
# Epoch 17/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 49s 150ms/step - loss: 2923.3486 - root_mean_squared_error: 54.0450 - val_loss: 860.9340 - val_root_mean_squared_error: 29.3506
# Epoch 18/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 48s 146ms/step - loss: 2622.9153 - root_mean_squared_error: 51.1737 - val_loss: 854.3713 - val_root_mean_squared_error: 29.2424
# Epoch 19/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 49s 149ms/step - loss: 2833.3350 - root_mean_squared_error: 53.2102 - val_loss: 910.1467 - val_root_mean_squared_error: 30.1895
# Epoch 20/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 49s 149ms/step - loss: 2633.0342 - root_mean_squared_error: 51.2918 - val_loss: 826.5404 - val_root_mean_squared_error: 28.7831
# Epoch 21/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 51s 155ms/step - loss: 2691.9187 - root_mean_squared_error: 51.8669 - val_loss: 815.4710 - val_root_mean_squared_error: 28.5820
# Epoch 22/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 49s 148ms/step - loss: 2426.0037 - root_mean_squared_error: 49.2426 - val_loss: 832.6362 - val_root_mean_squared_error: 28.8841
# Epoch 23/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 53s 161ms/step - loss: 2460.4629 - root_mean_squared_error: 49.5746 - val_loss: 879.9929 - val_root_mean_squared_error: 29.6846
# Epoch 24/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 51s 155ms/step - loss: 2561.0027 - root_mean_squared_error: 50.5667 - val_loss: 869.1121 - val_root_mean_squared_error: 29.5090
# Epoch 25/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 49s 149ms/step - loss: 2673.4688 - root_mean_squared_error: 51.6816 - val_loss: 854.7799 - val_root_mean_squared_error: 29.2610
# Epoch 26/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 48s 145ms/step - loss: 2575.8726 - root_mean_squared_error: 50.7407 - val_loss: 793.1140 - val_root_mean_squared_error: 28.1932
# Epoch 27/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 45s 138ms/step - loss: 2438.0977 - root_mean_squared_error: 49.3613 - val_loss: 921.2840 - val_root_mean_squared_error: 30.3479
# Epoch 28/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 46s 139ms/step - loss: 2424.2437 - root_mean_squared_error: 49.1931 - val_loss: 848.0781 - val_root_mean_squared_error: 29.1424
# Epoch 29/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 63s 191ms/step - loss: 2412.4758 - root_mean_squared_error: 49.0810 - val_loss: 845.2098 - val_root_mean_squared_error: 29.1052
# Epoch 30/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 179ms/step - loss: 2499.8540 - root_mean_squared_error: 49.9733 - val_loss: 841.7564 - val_root_mean_squared_error: 29.0403
# Epoch 31/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - loss: 2195.2153 - root_mean_squared_error: 46.7898 - val_loss: 960.4734 - val_root_mean_squared_error: 31.0131
# Epoch 32/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 178ms/step - loss: 2564.7378 - root_mean_squared_error: 50.6100 - val_loss: 812.3923 - val_root_mean_squared_error: 28.5205
# Epoch 33/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - loss: 2409.8328 - root_mean_squared_error: 49.0328 - val_loss: 897.3274 - val_root_mean_squared_error: 29.9608
# Epoch 34/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - loss: 2380.4211 - root_mean_squared_error: 48.7453 - val_loss: 888.1652 - val_root_mean_squared_error: 29.8012
# Epoch 35/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 178ms/step - loss: 2480.8867 - root_mean_squared_error: 49.7005 - val_loss: 898.5649 - val_root_mean_squared_error: 29.9778
# Epoch 36/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 181ms/step - loss: 2266.9248 - root_mean_squared_error: 47.5913 - val_loss: 913.9280 - val_root_mean_squared_error: 30.2581
# Epoch 37/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 179ms/step - loss: 2361.6606 - root_mean_squared_error: 48.5230 - val_loss: 796.7812 - val_root_mean_squared_error: 28.2430
# Epoch 38/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 181ms/step - loss: 2206.9094 - root_mean_squared_error: 46.9641 - val_loss: 923.5825 - val_root_mean_squared_error: 30.4142
# Epoch 39/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - loss: 2265.4744 - root_mean_squared_error: 47.5343 - val_loss: 980.4377 - val_root_mean_squared_error: 31.3247
# Epoch 40/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - loss: 2216.3560 - root_mean_squared_error: 47.0374 - val_loss: 871.4994 - val_root_mean_squared_error: 29.5455
# Epoch 41/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 51s 154ms/step - loss: 2109.0442 - root_mean_squared_error: 45.8921 - val_loss: 949.6207 - val_root_mean_squared_error: 30.8053
# Epoch 42/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 178ms/step - loss: 2091.3167 - root_mean_squared_error: 45.7102 - val_loss: 953.3642 - val_root_mean_squared_error: 30.9015
# Epoch 43/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 179ms/step - loss: 2162.3633 - root_mean_squared_error: 46.4911 - val_loss: 879.7927 - val_root_mean_squared_error: 29.6896
# Epoch 44/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 179ms/step - loss: 2106.4841 - root_mean_squared_error: 45.8824 - val_loss: 853.7679 - val_root_mean_squared_error: 29.2284
# Epoch 45/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 59s 178ms/step - loss: 2102.9526 - root_mean_squared_error: 45.8470 - val_loss: 858.7681 - val_root_mean_squared_error: 29.3112
# Epoch 46/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 63s 192ms/step - loss: 2119.1387 - root_mean_squared_error: 46.0262 - val_loss: 911.5251 - val_root_mean_squared_error: 30.2091
# Epoch 47/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 48s 145ms/step - loss: 1993.9773 - root_mean_squared_error: 44.6377 - val_loss: 888.5869 - val_root_mean_squared_error: 29.8335
# Epoch 48/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 53s 162ms/step - loss: 1939.2300 - root_mean_squared_error: 44.0273 - val_loss: 864.8829 - val_root_mean_squared_error: 29.4128
# Epoch 49/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 50s 152ms/step - loss: 2112.5781 - root_mean_squared_error: 45.9105 - val_loss: 1004.2803 - val_root_mean_squared_error: 31.7045
# Epoch 50/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 50s 152ms/step - loss: 2035.0839 - root_mean_squared_error: 45.0900 - val_loss: 936.5572 - val_root_mean_squared_error: 30.6278

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

df = pd.read_csv("../meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

required_cols = ['SOLAR_RADIATION']
df = df[required_cols]

temp = df['SOLAR_RADIATION']

plt.figure(figsize=(10, 6))
plt.plot(df['SOLAR_RADIATION'], label='Солнечная радиация', color='blue')

# Настройка графика
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# предсказание, основанное не предыдущем суточном дне
def df_to_X_y(df, window_size=24):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE = 24
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)

# Размеры выборок
n = len(df)
train_size = int(n * 0.75)
val_size = int(n * 0.125)
test_size = n - train_size - val_size

X_train1, y_train1 = X1[:train_size], y1[:train_size]
X_val1, y_val1 = X1[train_size:train_size + val_size], y1[train_size:train_size + val_size]
X_test1, y_test1 = X1[train_size + val_size:], y1[train_size + val_size:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((39408, 24, 1), (39408,), (6568, 24, 1), (6568,), (6545, 24, 1), (6545,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, 1)))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(32))
model2.add(Dropout(0.5))
model2.add(Dense(16, activation='relu'))
model2.add(Dense(8, activation='relu'))
model2.add(Dense(1, activation='relu'))
model2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 24, 64)              │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 24, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 24, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 63,009 (246.13 KB)
#  Trainable params: 63,009 (246.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Настройки обратного вызова и компиляции модели
model_save_path = 'model2/model2-SOLAR_RADIATION.keras'  
cp2 = ModelCheckpoint(model_save_path, save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
# Обучение модели
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 54s 38ms/step - loss: 71065.4531 - root_mean_squared_error: 266.4771 - val_loss: 63642.2188 - val_root_mean_squared_error: 252.2741
# Epoch 2/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - loss: 53376.9805 - root_mean_squared_error: 230.9208 - val_loss: 39366.8164 - val_root_mean_squared_error: 198.4107
# Epoch 3/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - loss: 32574.0449 - root_mean_squared_error: 180.2952 - val_loss: 20449.3809 - val_root_mean_squared_error: 143.0013
# Epoch 4/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - loss: 17620.6113 - root_mean_squared_error: 132.5674 - val_loss: 10966.0947 - val_root_mean_squared_error: 104.7191
# Epoch 5/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - loss: 10713.5820 - root_mean_squared_error: 103.4344 - val_loss: 7033.3662 - val_root_mean_squared_error: 83.8652
# Epoch 6/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 44s 36ms/step - loss: 8042.5010 - root_mean_squared_error: 89.6449 - val_loss: 5974.5010 - val_root_mean_squared_error: 77.2949
# Epoch 7/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 49s 40ms/step - loss: 7008.5254 - root_mean_squared_error: 83.6912 - val_loss: 4716.8174 - val_root_mean_squared_error: 68.6791
# Epoch 8/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 49s 40ms/step - loss: 6701.4219 - root_mean_squared_error: 81.8362 - val_loss: 4405.0996 - val_root_mean_squared_error: 66.3709
# Epoch 9/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 52s 42ms/step - loss: 6329.3789 - root_mean_squared_error: 79.5500 - val_loss: 4127.2490 - val_root_mean_squared_error: 64.2437
# Epoch 10/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 55s 44ms/step - loss: 6158.3428 - root_mean_squared_error: 78.4655 - val_loss: 3724.5627 - val_root_mean_squared_error: 61.0292
# Epoch 11/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 56s 46ms/step - loss: 5969.5298 - root_mean_squared_error: 77.2500 - val_loss: 4138.4648 - val_root_mean_squared_error: 64.3309
# Epoch 12/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 56s 45ms/step - loss: 5728.2246 - root_mean_squared_error: 75.6791 - val_loss: 3559.0220 - val_root_mean_squared_error: 59.6575
# Epoch 13/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - loss: 5468.1450 - root_mean_squared_error: 73.9397 - val_loss: 3481.1721 - val_root_mean_squared_error: 59.0015
# Epoch 14/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 54s 44ms/step - loss: 5771.9595 - root_mean_squared_error: 75.8804 - val_loss: 3456.9873 - val_root_mean_squared_error: 58.7962
# Epoch 15/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 57s 46ms/step - loss: 5625.5244 - root_mean_squared_error: 74.9826 - val_loss: 3512.6196 - val_root_mean_squared_error: 59.2674
# Epoch 16/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 58s 47ms/step - loss: 5404.6167 - root_mean_squared_error: 73.5007 - val_loss: 3474.3867 - val_root_mean_squared_error: 58.9439
# Epoch 17/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 84s 49ms/step - loss: 5348.3691 - root_mean_squared_error: 73.1290 - val_loss: 3370.2693 - val_root_mean_squared_error: 58.0540
# Epoch 18/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 62s 50ms/step - loss: 5208.8477 - root_mean_squared_error: 72.1655 - val_loss: 3551.0981 - val_root_mean_squared_error: 59.5911
# Epoch 19/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 56s 46ms/step - loss: 5198.5859 - root_mean_squared_error: 72.0797 - val_loss: 4112.6631 - val_root_mean_squared_error: 64.1301
# Epoch 20/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 52s 42ms/step - loss: 5100.6870 - root_mean_squared_error: 71.4146 - val_loss: 3523.3748 - val_root_mean_squared_error: 59.3580
# Epoch 21/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 54s 44ms/step - loss: 4946.4155 - root_mean_squared_error: 70.3003 - val_loss: 3199.0625 - val_root_mean_squared_error: 56.5603
# Epoch 22/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 54s 44ms/step - loss: 5009.9888 - root_mean_squared_error: 70.7566 - val_loss: 3213.0229 - val_root_mean_squared_error: 56.6835
# Epoch 23/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 52s 43ms/step - loss: 4940.5576 - root_mean_squared_error: 70.2872 - val_loss: 3359.0010 - val_root_mean_squared_error: 57.9569
# Epoch 24/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 58s 47ms/step - loss: 4990.9497 - root_mean_squared_error: 70.6307 - val_loss: 3284.3494 - val_root_mean_squared_error: 57.3092
# Epoch 25/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 54s 44ms/step - loss: 4732.1431 - root_mean_squared_error: 68.7778 - val_loss: 3203.0310 - val_root_mean_squared_error: 56.5953
# Epoch 26/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 82s 43ms/step - loss: 4811.9976 - root_mean_squared_error: 69.3575 - val_loss: 3097.8662 - val_root_mean_squared_error: 55.6585
# Epoch 27/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 48s 39ms/step - loss: 4811.5884 - root_mean_squared_error: 69.3597 - val_loss: 3788.3457 - val_root_mean_squared_error: 61.5495
# Epoch 28/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - loss: 4904.1748 - root_mean_squared_error: 70.0041 - val_loss: 3200.9646 - val_root_mean_squared_error: 56.5771
# Epoch 29/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - loss: 4725.8242 - root_mean_squared_error: 68.7397 - val_loss: 3188.6038 - val_root_mean_squared_error: 56.4677
# Epoch 30/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - loss: 4809.5229 - root_mean_squared_error: 69.3465 - val_loss: 3428.1401 - val_root_mean_squared_error: 58.5503
# Epoch 31/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 44s 36ms/step - loss: 4554.8989 - root_mean_squared_error: 67.4630 - val_loss: 3332.1282 - val_root_mean_squared_error: 57.7246
# Epoch 32/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 51s 41ms/step - loss: 4682.6758 - root_mean_squared_error: 68.4215 - val_loss: 3256.0332 - val_root_mean_squared_error: 57.0617
# Epoch 33/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 48s 39ms/step - loss: 4855.5635 - root_mean_squared_error: 69.6710 - val_loss: 3187.5444 - val_root_mean_squared_error: 56.4583
# Epoch 34/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 46s 38ms/step - loss: 4855.4146 - root_mean_squared_error: 69.6553 - val_loss: 3135.9565 - val_root_mean_squared_error: 55.9996
# Epoch 35/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - loss: 4626.0005 - root_mean_squared_error: 68.0053 - val_loss: 3184.9509 - val_root_mean_squared_error: 56.4354
# Epoch 36/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 51s 41ms/step - loss: 4657.8823 - root_mean_squared_error: 68.2368 - val_loss: 3119.2571 - val_root_mean_squared_error: 55.8503
# Epoch 37/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 54s 44ms/step - loss: 4540.3916 - root_mean_squared_error: 67.3785 - val_loss: 3142.6787 - val_root_mean_squared_error: 56.0596
# Epoch 38/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 76s 39ms/step - loss: 4437.4180 - root_mean_squared_error: 66.6000 - val_loss: 3297.8489 - val_root_mean_squared_error: 57.4269
# Epoch 39/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 58s 47ms/step - loss: 4480.1230 - root_mean_squared_error: 66.9228 - val_loss: 3168.6331 - val_root_mean_squared_error: 56.2906
# Epoch 40/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 53s 43ms/step - loss: 4512.9346 - root_mean_squared_error: 67.1627 - val_loss: 3094.0742 - val_root_mean_squared_error: 55.6244
# Epoch 41/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 51s 41ms/step - loss: 4483.7744 - root_mean_squared_error: 66.9478 - val_loss: 3176.3149 - val_root_mean_squared_error: 56.3588
# Epoch 42/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - loss: 4653.1104 - root_mean_squared_error: 68.1768 - val_loss: 3016.2600 - val_root_mean_squared_error: 54.9205
# Epoch 43/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - loss: 4524.5410 - root_mean_squared_error: 67.2519 - val_loss: 3107.6855 - val_root_mean_squared_error: 55.7466
# Epoch 44/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 50s 41ms/step - loss: 4397.6777 - root_mean_squared_error: 66.3020 - val_loss: 3277.2451 - val_root_mean_squared_error: 57.2472
# Epoch 45/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 59s 48ms/step - loss: 4584.6113 - root_mean_squared_error: 67.6733 - val_loss: 3219.3284 - val_root_mean_squared_error: 56.7391
# Epoch 46/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - loss: 4321.4614 - root_mean_squared_error: 65.7188 - val_loss: 3101.9619 - val_root_mean_squared_error: 55.6953
# Epoch 47/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 55s 45ms/step - loss: 4477.0161 - root_mean_squared_error: 66.8905 - val_loss: 3295.1858 - val_root_mean_squared_error: 57.4037
# Epoch 48/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 57s 46ms/step - loss: 4419.5044 - root_mean_squared_error: 66.4744 - val_loss: 3083.5359 - val_root_mean_squared_error: 55.5296
# Epoch 49/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 55s 44ms/step - loss: 4221.4355 - root_mean_squared_error: 64.8967 - val_loss: 3070.4321 - val_root_mean_squared_error: 55.4115
# Epoch 50/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 54s 44ms/step - loss: 4410.6929 - root_mean_squared_error: 66.3940 - val_loss: 3175.5728 - val_root_mean_squared_error: 56.3522

# %%
# Сохранение всей модели на диск
model_save_path = 'model2/model2-SOLAR_RADIATION.keras'
model2.save(model_save_path)
print(f"Модель сохранена в {model_save_path}")
# Out:
# Модель сохранена в model2/model2-SOLAR_RADIATION.keras

# %%
from keras.models import load_model
model = load_model('model2/model2-SOLAR_RADIATION.keras')

# %%
# Прогнозирование на тестовых данных
y_pred = model.predict(X_test1)

# Вывод предсказаний
print(y_pred)
# Out:
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step
# [[  0.     ]
#  [  0.     ]
#  [  0.     ]
#  ...
#  [553.3451 ]
#  [420.40613]
#  [337.25528]]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=24):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='h')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, 1)
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append(prediction[0, 0])
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = temp.values[-WINDOW_SIZE:]
last_known_dates = temp.index[-WINDOW_SIZE:]

# Прогнозирование на 3 шага вперед
future_steps = 24
future_dates, predictions = predict_future(model, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 2024-06-15 14:00:00: 473.9624938964844
# 2024-06-15 15:00:00: 435.5089111328125
# 2024-06-15 16:00:00: 360.54864501953125
# 2024-06-15 17:00:00: 265.70965576171875
# 2024-06-15 18:00:00: 171.1828155517578
# 2024-06-15 19:00:00: 70.09956359863281
# 2024-06-15 20:00:00: 0.0
# 2024-06-15 21:00:00: 0.0
# 2024-06-15 22:00:00: 0.0
# 2024-06-15 23:00:00: 0.0
# 2024-06-16 00:00:00: 0.0
# 2024-06-16 01:00:00: 0.0
# 2024-06-16 02:00:00: 0.0
# 2024-06-16 03:00:00: 0.0
# 2024-06-16 04:00:00: 0.0
# 2024-06-16 05:00:00: 0.0
# 2024-06-16 06:00:00: 39.150909423828125
# 2024-06-16 07:00:00: 144.3065643310547
# 2024-06-16 08:00:00: 259.083740234375
# 2024-06-16 09:00:00: 461.4923095703125
# 2024-06-16 10:00:00: 634.406982421875
# 2024-06-16 11:00:00: 746.965576171875
# 2024-06-16 12:00:00: 800.7845458984375
# 2024-06-16 13:00:00: 795.6617431640625

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[700:900], label='Предсказанные значения', color='blue')
plt.plot(y_test1[700:900], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step

# %%
# Оценка MAE
mae = mean_absolute_error(y_test1, y_pred1)

# Оценка MSE
mse = mean_squared_error(y_test1, y_pred1)

# Оценка RMSE
rmse = np.sqrt(mse)

# Оценка R^2
r2 = r2_score(y_test1, y_pred1)

print("Средняя абсолютная ошибка (MAE):", mae)
print("Средняя квадратичная ошибка (MSE):", mse)
print("Корень из среднеквадратичной ошибки (RMSE):", rmse)
print("Коэффициент детерминации (R^2):", r2)
# Out:
# Средняя абсолютная ошибка (MAE): 18.69763813883954
# Средняя квадратичная ошибка (MSE): 1981.0842283722884
# Корень из среднеквадратичной ошибки (RMSE): 44.50937236551745
# Коэффициент детерминации (R^2): 0.9534729121606509
