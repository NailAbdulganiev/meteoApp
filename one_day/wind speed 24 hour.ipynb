# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

df = pd.read_csv("../meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

required_cols = ['WIND_SPEED']
df = df[required_cols]

temp = df['WIND_SPEED']

plt.figure(figsize=(10, 6))
plt.plot(df['WIND_SPEED'], label='Скорость ветра', color='blue')

# Настройка графика
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# предсказание, основанное не предыдущем суточном дне
def df_to_X_y(df, window_size=24):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE = 12
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)

# Размеры выборок
n = len(df)
train_size = int(n * 0.75)
val_size = int(n * 0.125)
test_size = n - train_size - val_size

X_train1, y_train1 = X1[:train_size], y1[:train_size]
X_val1, y_val1 = X1[train_size:train_size + val_size], y1[train_size:train_size + val_size]
X_test1, y_test1 = X1[train_size + val_size:], y1[train_size + val_size:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((39408, 12, 1), (39408,), (6568, 12, 1), (6568,), (6557, 12, 1), (6557,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, 1)))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(32))
model2.add(Dropout(0.5))
model2.add(Dense(16, activation='relu'))
model2.add(Dense(8, activation='relu'))
model2.add(Dense(1, activation='relu'))
model2.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_14 (LSTM)                       │ (None, 12, 64)              │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 12, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_15 (LSTM)                       │ (None, 12, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 12, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_16 (LSTM)                       │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_16 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 63,009 (246.13 KB)
#  Trainable params: 63,009 (246.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Настройки обратного вызова и компиляции модели
model_save_path = 'model2/model2-WIND_SPEED.keras'
cp2 = ModelCheckpoint(model_save_path, save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
# Обучение модели
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 27s 16ms/step - loss: 2.8435 - root_mean_squared_error: 1.6621 - val_loss: 0.5754 - val_root_mean_squared_error: 0.7585
# Epoch 2/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.8965 - root_mean_squared_error: 0.9466 - val_loss: 0.3887 - val_root_mean_squared_error: 0.6235
# Epoch 3/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.6991 - root_mean_squared_error: 0.8361 - val_loss: 0.3166 - val_root_mean_squared_error: 0.5627
# Epoch 4/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.6261 - root_mean_squared_error: 0.7912 - val_loss: 0.2937 - val_root_mean_squared_error: 0.5419
# Epoch 5/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.5768 - root_mean_squared_error: 0.7595 - val_loss: 0.2877 - val_root_mean_squared_error: 0.5363
# Epoch 6/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 0.5555 - root_mean_squared_error: 0.7453 - val_loss: 0.2749 - val_root_mean_squared_error: 0.5243
# Epoch 7/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.5317 - root_mean_squared_error: 0.7292 - val_loss: 0.2718 - val_root_mean_squared_error: 0.5213
# Epoch 8/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.5056 - root_mean_squared_error: 0.7110 - val_loss: 0.2701 - val_root_mean_squared_error: 0.5197
# Epoch 9/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.5006 - root_mean_squared_error: 0.7075 - val_loss: 0.2782 - val_root_mean_squared_error: 0.5275
# Epoch 10/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.4739 - root_mean_squared_error: 0.6883 - val_loss: 0.3060 - val_root_mean_squared_error: 0.5532
# Epoch 11/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.4877 - root_mean_squared_error: 0.6983 - val_loss: 0.2816 - val_root_mean_squared_error: 0.5307
# Epoch 12/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.4784 - root_mean_squared_error: 0.6916 - val_loss: 0.2874 - val_root_mean_squared_error: 0.5361
# Epoch 13/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4786 - root_mean_squared_error: 0.6917 - val_loss: 0.2923 - val_root_mean_squared_error: 0.5407
# Epoch 14/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.4643 - root_mean_squared_error: 0.6814 - val_loss: 0.2879 - val_root_mean_squared_error: 0.5365
# Epoch 15/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4638 - root_mean_squared_error: 0.6810 - val_loss: 0.3051 - val_root_mean_squared_error: 0.5524
# Epoch 16/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4528 - root_mean_squared_error: 0.6729 - val_loss: 0.3030 - val_root_mean_squared_error: 0.5505
# Epoch 17/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4448 - root_mean_squared_error: 0.6669 - val_loss: 0.2979 - val_root_mean_squared_error: 0.5458
# Epoch 18/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.4330 - root_mean_squared_error: 0.6579 - val_loss: 0.2940 - val_root_mean_squared_error: 0.5422
# Epoch 19/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.4508 - root_mean_squared_error: 0.6713 - val_loss: 0.2792 - val_root_mean_squared_error: 0.5284
# Epoch 20/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.4687 - root_mean_squared_error: 0.6843 - val_loss: 0.2892 - val_root_mean_squared_error: 0.5378
# Epoch 21/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.4589 - root_mean_squared_error: 0.6772 - val_loss: 0.2968 - val_root_mean_squared_error: 0.5448
# Epoch 22/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4387 - root_mean_squared_error: 0.6623 - val_loss: 0.3173 - val_root_mean_squared_error: 0.5633
# Epoch 23/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4488 - root_mean_squared_error: 0.6699 - val_loss: 0.3065 - val_root_mean_squared_error: 0.5536
# Epoch 24/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4288 - root_mean_squared_error: 0.6547 - val_loss: 0.2994 - val_root_mean_squared_error: 0.5472
# Epoch 25/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.4454 - root_mean_squared_error: 0.6673 - val_loss: 0.3073 - val_root_mean_squared_error: 0.5543
# Epoch 26/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 0.4407 - root_mean_squared_error: 0.6638 - val_loss: 0.3066 - val_root_mean_squared_error: 0.5537
# Epoch 27/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4336 - root_mean_squared_error: 0.6584 - val_loss: 0.2989 - val_root_mean_squared_error: 0.5467
# Epoch 28/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4371 - root_mean_squared_error: 0.6610 - val_loss: 0.3088 - val_root_mean_squared_error: 0.5557
# Epoch 29/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4307 - root_mean_squared_error: 0.6562 - val_loss: 0.3112 - val_root_mean_squared_error: 0.5578
# Epoch 30/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4268 - root_mean_squared_error: 0.6532 - val_loss: 0.3074 - val_root_mean_squared_error: 0.5544
# Epoch 31/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4313 - root_mean_squared_error: 0.6567 - val_loss: 0.3064 - val_root_mean_squared_error: 0.5535
# Epoch 32/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4428 - root_mean_squared_error: 0.6654 - val_loss: 0.3159 - val_root_mean_squared_error: 0.5621
# Epoch 33/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4299 - root_mean_squared_error: 0.6554 - val_loss: 0.2927 - val_root_mean_squared_error: 0.5410
# Epoch 34/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4521 - root_mean_squared_error: 0.6719 - val_loss: 0.3095 - val_root_mean_squared_error: 0.5564
# Epoch 35/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4187 - root_mean_squared_error: 0.6469 - val_loss: 0.3122 - val_root_mean_squared_error: 0.5588
# Epoch 36/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4168 - root_mean_squared_error: 0.6455 - val_loss: 0.3077 - val_root_mean_squared_error: 0.5547
# Epoch 37/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4254 - root_mean_squared_error: 0.6521 - val_loss: 0.3029 - val_root_mean_squared_error: 0.5503
# Epoch 38/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - loss: 0.4205 - root_mean_squared_error: 0.6483 - val_loss: 0.3171 - val_root_mean_squared_error: 0.5631
# Epoch 39/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4299 - root_mean_squared_error: 0.6555 - val_loss: 0.3090 - val_root_mean_squared_error: 0.5559
# Epoch 40/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4134 - root_mean_squared_error: 0.6429 - val_loss: 0.3086 - val_root_mean_squared_error: 0.5555
# Epoch 41/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4211 - root_mean_squared_error: 0.6489 - val_loss: 0.3208 - val_root_mean_squared_error: 0.5664
# Epoch 42/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4229 - root_mean_squared_error: 0.6502 - val_loss: 0.3120 - val_root_mean_squared_error: 0.5586
# Epoch 43/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - loss: 0.4145 - root_mean_squared_error: 0.6438 - val_loss: 0.3109 - val_root_mean_squared_error: 0.5576
# Epoch 44/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - loss: 0.4166 - root_mean_squared_error: 0.6454 - val_loss: 0.3113 - val_root_mean_squared_error: 0.5579
# Epoch 45/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4058 - root_mean_squared_error: 0.6370 - val_loss: 0.3130 - val_root_mean_squared_error: 0.5595
# Epoch 46/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 0.4224 - root_mean_squared_error: 0.6498 - val_loss: 0.3055 - val_root_mean_squared_error: 0.5527
# Epoch 47/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4170 - root_mean_squared_error: 0.6457 - val_loss: 0.3062 - val_root_mean_squared_error: 0.5533
# Epoch 48/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.4116 - root_mean_squared_error: 0.6415 - val_loss: 0.3079 - val_root_mean_squared_error: 0.5549
# Epoch 49/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - loss: 0.4108 - root_mean_squared_error: 0.6409 - val_loss: 0.3264 - val_root_mean_squared_error: 0.5713
# Epoch 50/50
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 0.4153 - root_mean_squared_error: 0.6444 - val_loss: 0.3043 - val_root_mean_squared_error: 0.5517

# %%
# Сохранение всей модели на диск
model_save_path = 'model2/model2-WIND_SPEED.keras'
model2.save(model_save_path)
print(f"Модель сохранена в {model_save_path}")
# Out:
# Модель сохранена в model2/model2-WIND_SPEED.keras

# %%
from keras.models import load_model
model = load_model('model2/model2-WIND_SPEED.keras')

# %%
# Прогнозирование на тестовых данных
y_pred = model.predict(X_test1)

# Вывод предсказаний
print(y_pred)
# Out:
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# [[0.17612466]
#  [0.17573941]
#  [0.1754142 ]
#  ...
#  [1.0088602 ]
#  [0.69852394]
#  [0.340553  ]]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=10):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='h')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, 1)
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append(prediction[0, 0])
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = temp.values[-WINDOW_SIZE:]
last_known_dates = temp.index[-WINDOW_SIZE:]

# Прогнозирование на 3 шага вперед
future_steps = 24
future_dates, predictions = predict_future(model, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2024-06-15 14:00:00: 0.9000898599624634
# 2024-06-15 15:00:00: 0.8606300950050354
# 2024-06-15 16:00:00: 0.8149896264076233
# 2024-06-15 17:00:00: 0.7517805695533752
# 2024-06-15 18:00:00: 0.6688400506973267
# 2024-06-15 19:00:00: 0.5750894546508789
# 2024-06-15 20:00:00: 0.4745895564556122
# 2024-06-15 21:00:00: 0.3731552064418793
# 2024-06-15 22:00:00: 0.32038813829421997
# 2024-06-15 23:00:00: 0.2914588153362274
# 2024-06-16 00:00:00: 0.2713261544704437
# 2024-06-16 01:00:00: 0.25682729482650757
# 2024-06-16 02:00:00: 0.2506624758243561
# 2024-06-16 03:00:00: 0.25055667757987976
# 2024-06-16 04:00:00: 0.2543904185295105
# 2024-06-16 05:00:00: 0.2609381377696991
# 2024-06-16 06:00:00: 0.26905032992362976
# 2024-06-16 07:00:00: 0.2775949537754059
# 2024-06-16 08:00:00: 0.28558748960494995
# 2024-06-16 09:00:00: 0.2923045754432678
# 2024-06-16 10:00:00: 0.2973809540271759
# 2024-06-16 11:00:00: 0.30097466707229614
# 2024-06-16 12:00:00: 0.3033530116081238
# 2024-06-16 13:00:00: 0.30472514033317566

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[700:800], label='Предсказанные значения', color='blue')
plt.plot(y_test1[700:800], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step

# %%
# Оценка MAE
mae = mean_absolute_error(y_test1, y_pred1)

# Оценка MSE
mse = mean_squared_error(y_test1, y_pred1)

# Оценка RMSE
rmse = np.sqrt(mse)

# Оценка R^2
r2 = r2_score(y_test1, y_pred1)

print("Средняя абсолютная ошибка (MAE):", mae)
print("Средняя квадратичная ошибка (MSE):", mse)
print("Корень из среднеквадратичной ошибки (RMSE):", rmse)
print("Коэффициент детерминации (R^2):", r2)
# Out:
# Средняя абсолютная ошибка (MAE): 0.44918266595982553
# Средняя квадратичная ошибка (MSE): 0.40194988027906664
# Корень из среднеквадратичной ошибки (RMSE): 0.6339951737032914
# Коэффициент детерминации (R^2): 0.8609804187629525
