# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

df = pd.read_csv("../meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

required_cols = ['WIND_SPEED']
df = df[required_cols]

temp = df['WIND_SPEED']

plt.figure(figsize=(10, 6))
plt.plot(df['WIND_SPEED'], label='Скорость ветра', color='blue')

# Настройка графика
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# предсказание, основанное не предыдущем суточном дне
def df_to_X_y(df, window_size=24):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE = 24
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)

# Размеры выборок
n = len(df)
train_size = int(n * 0.75)
val_size = int(n * 0.125)
test_size = n - train_size - val_size

X_train1, y_train1 = X1[:train_size], y1[:train_size]
X_val1, y_val1 = X1[train_size:train_size + val_size], y1[train_size:train_size + val_size]
X_test1, y_test1 = X1[train_size + val_size:], y1[train_size + val_size:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((26268, 24, 1), (26268,), (4378, 24, 1), (4378,), (4355, 24, 1), (4355,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, 1)))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(32))
model2.add(Dropout(0.5))
model2.add(Dense(16, activation='relu'))
model2.add(Dense(8, activation='relu'))
model2.add(Dense(1, activation='relu'))
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 24, 64)              │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 24, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 24, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 24, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 63,009 (246.13 KB)
#  Trainable params: 63,009 (246.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Настройки обратного вызова и компиляции модели
model_save_path = 'model2/model2-wind-speed.keras'
cp2 = ModelCheckpoint(model_save_path, save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
# Обучение модели
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 41s 40ms/step - loss: 3.4407 - root_mean_squared_error: 1.8410 - val_loss: 0.8522 - val_root_mean_squared_error: 0.9232
# Epoch 2/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 33s 40ms/step - loss: 1.0762 - root_mean_squared_error: 1.0370 - val_loss: 0.5953 - val_root_mean_squared_error: 0.7716
# Epoch 3/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 32s 39ms/step - loss: 0.8230 - root_mean_squared_error: 0.9071 - val_loss: 0.4688 - val_root_mean_squared_error: 0.6847
# Epoch 4/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 0.7039 - root_mean_squared_error: 0.8388 - val_loss: 0.3972 - val_root_mean_squared_error: 0.6302
# Epoch 5/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 32s 38ms/step - loss: 0.6419 - root_mean_squared_error: 0.8011 - val_loss: 0.3574 - val_root_mean_squared_error: 0.5979
# Epoch 6/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 42s 51ms/step - loss: 0.5720 - root_mean_squared_error: 0.7562 - val_loss: 0.3311 - val_root_mean_squared_error: 0.5754
# Epoch 7/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 36s 43ms/step - loss: 0.5575 - root_mean_squared_error: 0.7466 - val_loss: 0.3089 - val_root_mean_squared_error: 0.5558
# Epoch 8/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 34s 41ms/step - loss: 0.5246 - root_mean_squared_error: 0.7242 - val_loss: 0.3018 - val_root_mean_squared_error: 0.5493
# Epoch 9/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 35s 42ms/step - loss: 0.5104 - root_mean_squared_error: 0.7144 - val_loss: 0.2899 - val_root_mean_squared_error: 0.5384
# Epoch 10/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 32s 39ms/step - loss: 0.4949 - root_mean_squared_error: 0.7034 - val_loss: 0.2915 - val_root_mean_squared_error: 0.5399
# Epoch 11/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.4941 - root_mean_squared_error: 0.7029 - val_loss: 0.2811 - val_root_mean_squared_error: 0.5302
# Epoch 12/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 27s 33ms/step - loss: 0.4808 - root_mean_squared_error: 0.6934 - val_loss: 0.2852 - val_root_mean_squared_error: 0.5340
# Epoch 13/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 28s 34ms/step - loss: 0.4615 - root_mean_squared_error: 0.6793 - val_loss: 0.2800 - val_root_mean_squared_error: 0.5291
# Epoch 14/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 24s 30ms/step - loss: 0.4612 - root_mean_squared_error: 0.6791 - val_loss: 0.2832 - val_root_mean_squared_error: 0.5321
# Epoch 15/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - loss: 0.4439 - root_mean_squared_error: 0.6662 - val_loss: 0.2828 - val_root_mean_squared_error: 0.5318
# Epoch 16/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 0.4622 - root_mean_squared_error: 0.6798 - val_loss: 0.2793 - val_root_mean_squared_error: 0.5285
# Epoch 17/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - loss: 0.4442 - root_mean_squared_error: 0.6664 - val_loss: 0.2855 - val_root_mean_squared_error: 0.5343
# Epoch 18/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 26s 32ms/step - loss: 0.4478 - root_mean_squared_error: 0.6690 - val_loss: 0.2829 - val_root_mean_squared_error: 0.5319
# Epoch 19/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - loss: 0.4373 - root_mean_squared_error: 0.6612 - val_loss: 0.2806 - val_root_mean_squared_error: 0.5297
# Epoch 20/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 25s 31ms/step - loss: 0.4446 - root_mean_squared_error: 0.6667 - val_loss: 0.2836 - val_root_mean_squared_error: 0.5325
# Epoch 21/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 26s 31ms/step - loss: 0.4339 - root_mean_squared_error: 0.6587 - val_loss: 0.2806 - val_root_mean_squared_error: 0.5297
# Epoch 22/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 29s 36ms/step - loss: 0.4231 - root_mean_squared_error: 0.6504 - val_loss: 0.3006 - val_root_mean_squared_error: 0.5483
# Epoch 23/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 29s 35ms/step - loss: 0.4193 - root_mean_squared_error: 0.6474 - val_loss: 0.2857 - val_root_mean_squared_error: 0.5345
# Epoch 24/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 29s 36ms/step - loss: 0.4201 - root_mean_squared_error: 0.6481 - val_loss: 0.2813 - val_root_mean_squared_error: 0.5304
# Epoch 25/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 25s 31ms/step - loss: 0.4270 - root_mean_squared_error: 0.6534 - val_loss: 0.2833 - val_root_mean_squared_error: 0.5323
# Epoch 26/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 28s 34ms/step - loss: 0.4084 - root_mean_squared_error: 0.6388 - val_loss: 0.2880 - val_root_mean_squared_error: 0.5366
# Epoch 27/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 29s 35ms/step - loss: 0.4039 - root_mean_squared_error: 0.6355 - val_loss: 0.2813 - val_root_mean_squared_error: 0.5304
# Epoch 28/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 24s 29ms/step - loss: 0.4144 - root_mean_squared_error: 0.6438 - val_loss: 0.2812 - val_root_mean_squared_error: 0.5303
# Epoch 29/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - loss: 0.4087 - root_mean_squared_error: 0.6393 - val_loss: 0.2817 - val_root_mean_squared_error: 0.5308
# Epoch 30/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 27s 33ms/step - loss: 0.4040 - root_mean_squared_error: 0.6356 - val_loss: 0.2773 - val_root_mean_squared_error: 0.5265
# Epoch 31/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 28s 34ms/step - loss: 0.4006 - root_mean_squared_error: 0.6329 - val_loss: 0.2874 - val_root_mean_squared_error: 0.5361
# Epoch 32/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 29s 35ms/step - loss: 0.4012 - root_mean_squared_error: 0.6333 - val_loss: 0.2821 - val_root_mean_squared_error: 0.5312
# Epoch 33/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 26s 32ms/step - loss: 0.4031 - root_mean_squared_error: 0.6349 - val_loss: 0.2829 - val_root_mean_squared_error: 0.5319
# Epoch 34/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 26s 32ms/step - loss: 0.4114 - root_mean_squared_error: 0.6414 - val_loss: 0.2791 - val_root_mean_squared_error: 0.5283
# Epoch 35/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 26s 32ms/step - loss: 0.4029 - root_mean_squared_error: 0.6347 - val_loss: 0.2836 - val_root_mean_squared_error: 0.5326
# Epoch 36/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 24s 29ms/step - loss: 0.4120 - root_mean_squared_error: 0.6414 - val_loss: 0.2876 - val_root_mean_squared_error: 0.5363
# Epoch 37/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 25s 31ms/step - loss: 0.3998 - root_mean_squared_error: 0.6323 - val_loss: 0.2762 - val_root_mean_squared_error: 0.5255
# Epoch 38/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 26s 31ms/step - loss: 0.3956 - root_mean_squared_error: 0.6290 - val_loss: 0.2794 - val_root_mean_squared_error: 0.5286
# Epoch 39/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 27s 33ms/step - loss: 0.3952 - root_mean_squared_error: 0.6286 - val_loss: 0.2827 - val_root_mean_squared_error: 0.5317
# Epoch 40/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 27s 32ms/step - loss: 0.3936 - root_mean_squared_error: 0.6273 - val_loss: 0.2788 - val_root_mean_squared_error: 0.5280
# Epoch 41/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 27s 33ms/step - loss: 0.3951 - root_mean_squared_error: 0.6285 - val_loss: 0.2811 - val_root_mean_squared_error: 0.5302
# Epoch 42/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 25s 31ms/step - loss: 0.4003 - root_mean_squared_error: 0.6326 - val_loss: 0.2820 - val_root_mean_squared_error: 0.5310
# Epoch 43/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 27s 33ms/step - loss: 0.3983 - root_mean_squared_error: 0.6310 - val_loss: 0.2812 - val_root_mean_squared_error: 0.5303
# Epoch 44/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - loss: 0.3890 - root_mean_squared_error: 0.6237 - val_loss: 0.2784 - val_root_mean_squared_error: 0.5277
# Epoch 45/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 28s 34ms/step - loss: 0.3965 - root_mean_squared_error: 0.6297 - val_loss: 0.2823 - val_root_mean_squared_error: 0.5313
# Epoch 46/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 28s 34ms/step - loss: 0.3940 - root_mean_squared_error: 0.6277 - val_loss: 0.2771 - val_root_mean_squared_error: 0.5264
# Epoch 47/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 26s 32ms/step - loss: 0.3913 - root_mean_squared_error: 0.6255 - val_loss: 0.2812 - val_root_mean_squared_error: 0.5303
# Epoch 48/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 0.3889 - root_mean_squared_error: 0.6236 - val_loss: 0.2862 - val_root_mean_squared_error: 0.5350
# Epoch 49/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 26s 31ms/step - loss: 0.3909 - root_mean_squared_error: 0.6252 - val_loss: 0.2848 - val_root_mean_squared_error: 0.5337
# Epoch 50/50
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 26s 31ms/step - loss: 0.4077 - root_mean_squared_error: 0.6381 - val_loss: 0.2764 - val_root_mean_squared_error: 0.5257

# %%
# Сохранение всей модели на диск
model_save_path = 'model2/model2-wind-speed.keras'
model2.save(model_save_path)
print(f"Модель сохранена в {model_save_path}")
# Out:
# Модель сохранена в model2/model2-wind-speed.keras

# %%
from keras.models import load_model
model = load_model('model2/model2-wind-speed.keras')

# %%
# Прогнозирование на тестовых данных
y_pred = model.predict(X_test1)

# Вывод предсказаний
print(y_pred)
# Out:
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# [[2.0424676 ]
#  [1.4496136 ]
#  [2.0232868 ]
#  ...
#  [0.5252716 ]
#  [0.42108732]
#  [0.39837635]]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=10):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='h')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, 1)
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append(prediction[0, 0])
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = temp.values[-WINDOW_SIZE:]
last_known_dates = temp.index[-WINDOW_SIZE:]

# Прогнозирование на 3 шага вперед
future_steps = 1
future_dates, predictions = predict_future(model, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2024-05-31 15:00:00: 0.4668799936771393

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[700:800], label='Предсказанные значения', color='blue')
plt.plot(y_test1[700:800], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
# Оценка MAE
mae = mean_absolute_error(y_test1, y_pred1)

# Оценка MSE
mse = mean_squared_error(y_test1, y_pred1)

# Оценка RMSE
rmse = np.sqrt(mse)

# Оценка R^2
r2 = r2_score(y_test1, y_pred1)

print("Средняя абсолютная ошибка (MAE):", mae)
print("Средняя квадратичная ошибка (MSE):", mse)
print("Корень из среднеквадратичной ошибки (RMSE):", rmse)
print("Коэффициент детерминации (R^2):", r2)
# Out:
# Средняя абсолютная ошибка (MAE): 0.4335018914326992
# Средняя квадратичная ошибка (MSE): 0.377050294755961
# Корень из среднеквадратичной ошибки (RMSE): 0.614044212378849
# Коэффициент детерминации (R^2): 0.8780157162940349
