# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

df = pd.read_csv("../meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

required_cols = ['HC_RELATIVE_HUMIDITY']
df = df[required_cols]
df = df.resample('3h').mean()
temp = df['HC_RELATIVE_HUMIDITY']

plt.figure(figsize=(10, 6))
plt.plot(df['HC_RELATIVE_HUMIDITY'], label='Относительная влажность', color='blue')

# Настройка графика
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# предсказание, основанное не предыдущем суточном дне
def df_to_X_y(df, window_size=24):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE = 56
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)

# Размеры выборок
n = len(df)
train_size = int(n * 0.75)
val_size = int(n * 0.125)
test_size = n - train_size - val_size

X_train1, y_train1 = X1[:train_size], y1[:train_size]
X_val1, y_val1 = X1[train_size:train_size + val_size], y1[train_size:train_size + val_size]
X_test1, y_test1 = X1[train_size + val_size:], y1[train_size + val_size:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((13140, 56, 1), (13140,), (2190, 56, 1), (2190,), (2135, 56, 1), (2135,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, 1)))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(32))
model2.add(Dropout(0.5))
model2.add(Dense(16, activation='relu'))
model2.add(Dense(8, activation='relu'))
model2.add(Dense(1, activation='relu'))
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 56, 64)              │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 56, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 56, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 56, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 63,009 (246.13 KB)
#  Trainable params: 63,009 (246.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Настройки обратного вызова и компиляции модели
model_save_path = 'model2/model2-HC_RELATIVE_HUMIDITY.keras'  
cp2 = ModelCheckpoint(model_save_path, save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
# Обучение модели
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 61s 105ms/step - loss: 481.6122 - root_mean_squared_error: 21.9284 - val_loss: 734.8423 - val_root_mean_squared_error: 27.1080
# Epoch 2/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 381.8134 - root_mean_squared_error: 19.5284 - val_loss: 538.4139 - val_root_mean_squared_error: 23.2037
# Epoch 3/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 93ms/step - loss: 295.1791 - root_mean_squared_error: 17.1653 - val_loss: 388.3286 - val_root_mean_squared_error: 19.7061
# Epoch 4/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 239.3412 - root_mean_squared_error: 15.4567 - val_loss: 296.8186 - val_root_mean_squared_error: 17.2284
# Epoch 5/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 93ms/step - loss: 194.3995 - root_mean_squared_error: 13.9378 - val_loss: 241.0136 - val_root_mean_squared_error: 15.5246
# Epoch 6/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 195.1225 - root_mean_squared_error: 13.9498 - val_loss: 208.8588 - val_root_mean_squared_error: 14.4519
# Epoch 7/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 174.8646 - root_mean_squared_error: 13.2174 - val_loss: 189.7195 - val_root_mean_squared_error: 13.7739
# Epoch 8/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - loss: 160.5894 - root_mean_squared_error: 12.6658 - val_loss: 177.3496 - val_root_mean_squared_error: 13.3173
# Epoch 9/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 154.5860 - root_mean_squared_error: 12.4211 - val_loss: 168.4349 - val_root_mean_squared_error: 12.9782
# Epoch 10/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 153.4208 - root_mean_squared_error: 12.3807 - val_loss: 168.0792 - val_root_mean_squared_error: 12.9645
# Epoch 11/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 94ms/step - loss: 143.4649 - root_mean_squared_error: 11.9641 - val_loss: 160.5805 - val_root_mean_squared_error: 12.6720
# Epoch 12/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 144.3773 - root_mean_squared_error: 11.9959 - val_loss: 158.6160 - val_root_mean_squared_error: 12.5943
# Epoch 13/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 146.8501 - root_mean_squared_error: 12.1151 - val_loss: 156.1430 - val_root_mean_squared_error: 12.4957
# Epoch 14/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 150.8018 - root_mean_squared_error: 12.2782 - val_loss: 155.4497 - val_root_mean_squared_error: 12.4679
# Epoch 15/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 42s 96ms/step - loss: 154.3286 - root_mean_squared_error: 12.4161 - val_loss: 153.7541 - val_root_mean_squared_error: 12.3998
# Epoch 16/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 97ms/step - loss: 148.8929 - root_mean_squared_error: 12.1955 - val_loss: 153.4122 - val_root_mean_squared_error: 12.3860
# Epoch 17/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 144.3234 - root_mean_squared_error: 12.0103 - val_loss: 151.9866 - val_root_mean_squared_error: 12.3283
# Epoch 18/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 97ms/step - loss: 151.8387 - root_mean_squared_error: 12.3177 - val_loss: 151.1234 - val_root_mean_squared_error: 12.2932
# Epoch 19/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 154.5946 - root_mean_squared_error: 12.4064 - val_loss: 150.8706 - val_root_mean_squared_error: 12.2829
# Epoch 20/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 147.3186 - root_mean_squared_error: 12.1336 - val_loss: 150.1393 - val_root_mean_squared_error: 12.2531
# Epoch 21/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 42s 96ms/step - loss: 146.4049 - root_mean_squared_error: 12.0937 - val_loss: 152.1353 - val_root_mean_squared_error: 12.3343
# Epoch 22/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 96ms/step - loss: 142.5038 - root_mean_squared_error: 11.9263 - val_loss: 149.6991 - val_root_mean_squared_error: 12.2352
# Epoch 23/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 139.8703 - root_mean_squared_error: 11.8169 - val_loss: 151.0802 - val_root_mean_squared_error: 12.2915
# Epoch 24/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 97ms/step - loss: 152.8265 - root_mean_squared_error: 12.3517 - val_loss: 150.1256 - val_root_mean_squared_error: 12.2526
# Epoch 25/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 141.6771 - root_mean_squared_error: 11.8990 - val_loss: 147.8109 - val_root_mean_squared_error: 12.1578
# Epoch 26/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 149.5760 - root_mean_squared_error: 12.2245 - val_loss: 147.0058 - val_root_mean_squared_error: 12.1246
# Epoch 27/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 136.1202 - root_mean_squared_error: 11.6564 - val_loss: 146.9535 - val_root_mean_squared_error: 12.1224
# Epoch 28/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 131.2571 - root_mean_squared_error: 11.4322 - val_loss: 148.0682 - val_root_mean_squared_error: 12.1683
# Epoch 29/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - loss: 148.7435 - root_mean_squared_error: 12.1781 - val_loss: 145.9359 - val_root_mean_squared_error: 12.0804
# Epoch 30/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 143.6028 - root_mean_squared_error: 11.9730 - val_loss: 146.0489 - val_root_mean_squared_error: 12.0851
# Epoch 31/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 42s 102ms/step - loss: 145.1388 - root_mean_squared_error: 12.0340 - val_loss: 146.7945 - val_root_mean_squared_error: 12.1159
# Epoch 32/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 35s 86ms/step - loss: 142.1547 - root_mean_squared_error: 11.9210 - val_loss: 148.5371 - val_root_mean_squared_error: 12.1876
# Epoch 33/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 91ms/step - loss: 141.4204 - root_mean_squared_error: 11.8843 - val_loss: 146.9483 - val_root_mean_squared_error: 12.1222
# Epoch 34/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 144.8977 - root_mean_squared_error: 12.0303 - val_loss: 145.5642 - val_root_mean_squared_error: 12.0650
# Epoch 35/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 96ms/step - loss: 137.0098 - root_mean_squared_error: 11.6989 - val_loss: 147.5757 - val_root_mean_squared_error: 12.1481
# Epoch 36/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 143.7153 - root_mean_squared_error: 11.9852 - val_loss: 146.0516 - val_root_mean_squared_error: 12.0852
# Epoch 37/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 139.6130 - root_mean_squared_error: 11.8042 - val_loss: 144.8427 - val_root_mean_squared_error: 12.0351
# Epoch 38/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 142.0603 - root_mean_squared_error: 11.9144 - val_loss: 144.8795 - val_root_mean_squared_error: 12.0366
# Epoch 39/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - loss: 140.3013 - root_mean_squared_error: 11.8416 - val_loss: 146.0209 - val_root_mean_squared_error: 12.0839
# Epoch 40/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 96ms/step - loss: 151.4882 - root_mean_squared_error: 12.2952 - val_loss: 146.9005 - val_root_mean_squared_error: 12.1203
# Epoch 41/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 36s 88ms/step - loss: 145.5244 - root_mean_squared_error: 12.0347 - val_loss: 144.8607 - val_root_mean_squared_error: 12.0358
# Epoch 42/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 34s 81ms/step - loss: 142.3866 - root_mean_squared_error: 11.9299 - val_loss: 145.8112 - val_root_mean_squared_error: 12.0752
# Epoch 43/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 33s 81ms/step - loss: 136.4014 - root_mean_squared_error: 11.6754 - val_loss: 151.5060 - val_root_mean_squared_error: 12.3088
# Epoch 44/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 34s 81ms/step - loss: 138.5387 - root_mean_squared_error: 11.7600 - val_loss: 145.2238 - val_root_mean_squared_error: 12.0509
# Epoch 45/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - loss: 141.2564 - root_mean_squared_error: 11.8771 - val_loss: 145.9010 - val_root_mean_squared_error: 12.0789
# Epoch 46/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 27s 65ms/step - loss: 138.4248 - root_mean_squared_error: 11.7633 - val_loss: 144.2965 - val_root_mean_squared_error: 12.0123
# Epoch 47/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 26s 64ms/step - loss: 147.5582 - root_mean_squared_error: 12.1357 - val_loss: 144.7602 - val_root_mean_squared_error: 12.0316
# Epoch 48/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 27s 66ms/step - loss: 136.1633 - root_mean_squared_error: 11.6663 - val_loss: 144.2527 - val_root_mean_squared_error: 12.0105
# Epoch 49/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 26s 64ms/step - loss: 144.0994 - root_mean_squared_error: 11.9986 - val_loss: 143.1687 - val_root_mean_squared_error: 11.9653
# Epoch 50/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 27s 65ms/step - loss: 147.4211 - root_mean_squared_error: 12.1357 - val_loss: 144.4072 - val_root_mean_squared_error: 12.0170

# %%
# Сохранение всей модели на диск
model_save_path = 'model2/model2-HC_RELATIVE_HUMIDITY.keras'  
model2.save(model_save_path)
print(f"Модель сохранена в {model_save_path}")
# Out:
# Модель сохранена в model2/model2-HC_RELATIVE_HUMIDITY.keras

# %%
from keras.models import load_model
model = load_model('model2/model2-HC_RELATIVE_HUMIDITY.keras')

# %%
# Прогнозирование на тестовых данных
y_pred = model.predict(X_test1)

# Вывод предсказаний
print(y_pred)
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step
# [[37.570576]
#  [58.15887 ]
#  [70.02932 ]
#  ...
#  [73.044975]
#  [76.44955 ]
#  [50.532314]]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=24):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='3h')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, 1)
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append(prediction[0, 0])
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = temp.values[-WINDOW_SIZE:]
last_known_dates = temp.index[-WINDOW_SIZE:]

# Прогнозирование на 3 шага вперед
future_steps = 56
future_dates, predictions = predict_future(model, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2024-06-15 15:00:00: 46.19556427001953
# 2024-06-15 18:00:00: 46.71181869506836
# 2024-06-15 21:00:00: 57.65286636352539
# 2024-06-16 00:00:00: 70.02685546875
# 2024-06-16 03:00:00: 73.72727966308594
# 2024-06-16 06:00:00: 70.42349243164062
# 2024-06-16 09:00:00: 65.44910430908203
# 2024-06-16 12:00:00: 63.060794830322266
# 2024-06-16 15:00:00: 65.06478881835938
# 2024-06-16 18:00:00: 69.09815216064453
# 2024-06-16 21:00:00: 71.16425323486328
# 2024-06-17 00:00:00: 70.36910247802734
# 2024-06-17 03:00:00: 68.4187240600586
# 2024-06-17 06:00:00: 67.26505279541016
# 2024-06-17 09:00:00: 67.71570587158203
# 2024-06-17 12:00:00: 69.01615142822266
# 2024-06-17 15:00:00: 69.83325958251953
# 2024-06-17 18:00:00: 69.65679931640625
# 2024-06-17 21:00:00: 68.96378326416016
# 2024-06-18 00:00:00: 68.49101257324219
# 2024-06-18 03:00:00: 68.58060455322266
# 2024-06-18 06:00:00: 69.00647735595703
# 2024-06-18 09:00:00: 69.31555938720703
# 2024-06-18 12:00:00: 69.2873764038086
# 2024-06-18 15:00:00: 69.05010986328125
# 2024-06-18 18:00:00: 68.8648452758789
# 2024-06-18 21:00:00: 68.87223815917969
# 2024-06-19 00:00:00: 69.0130615234375
# 2024-06-19 03:00:00: 69.12979888916016
# 2024-06-19 06:00:00: 69.1281967163086
# 2024-06-19 09:00:00: 69.03645324707031
# 2024-06-19 12:00:00: 68.95855712890625
# 2024-06-19 15:00:00: 68.95476531982422
# 2024-06-19 18:00:00: 69.00654602050781
# 2024-06-19 21:00:00: 69.05429077148438
# 2024-06-20 00:00:00: 69.05896759033203
# 2024-06-20 03:00:00: 69.0289535522461
# 2024-06-20 06:00:00: 69.00678253173828
# 2024-06-20 09:00:00: 69.0191879272461
# 2024-06-20 12:00:00: 69.05671691894531
# 2024-06-20 15:00:00: 69.1025161743164
# 2024-06-20 18:00:00: 69.12535858154297
# 2024-06-20 21:00:00: 69.14558410644531
# 2024-06-21 00:00:00: 69.2965316772461
# 2024-06-21 03:00:00: 69.43553161621094
# 2024-06-21 06:00:00: 69.47199249267578
# 2024-06-21 09:00:00: 69.43165588378906
# 2024-06-21 12:00:00: 69.40953063964844
# 2024-06-21 15:00:00: 69.4826889038086
# 2024-06-21 18:00:00: 69.63350677490234
# 2024-06-21 21:00:00: 69.7682876586914
# 2024-06-22 00:00:00: 69.8121337890625
# 2024-06-22 03:00:00: 69.77666473388672
# 2024-06-22 06:00:00: 69.7232894897461
# 2024-06-22 09:00:00: 69.70427703857422
# 2024-06-22 12:00:00: 69.73274993896484

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[700:900], label='Предсказанные значения', color='blue')
plt.plot(y_test1[700:900], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение') 
plt.legend()
plt.show()
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step

# %%
# Оценка MAE
mae = mean_absolute_error(y_test1, y_pred1)

# Оценка MSE
mse = mean_squared_error(y_test1, y_pred1)

# Оценка RMSE
rmse = np.sqrt(mse)

# Оценка R^2
r2 = r2_score(y_test1, y_pred1)

print("Средняя абсолютная ошибка (MAE):", mae)
print("Средняя квадратичная ошибка (MSE):", mse)
print("Корень из среднеквадратичной ошибки (RMSE):", rmse)
print("Коэффициент детерминации (R^2):", r2)
# Out:
# Средняя абсолютная ошибка (MAE): 9.873667923353594
# Средняя квадратичная ошибка (MSE): 324.39985291226463
# Корень из среднеквадратичной ошибки (RMSE): 18.011103600619943
# Коэффициент детерминации (R^2): 0.7529081069027759
