# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

df = pd.read_csv("../meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

required_cols = ['DEW_POINT']
df = df[required_cols]
df = df.resample('3h').mean()
temp = df['DEW_POINT']

plt.figure(figsize=(10, 6))
plt.plot(df['DEW_POINT'], label='Точка росы', color='blue')

# Настройка графика
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# предсказание, основанное не предыдущем суточном дне
def df_to_X_y(df, window_size=24):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE = 56
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)

# Размеры выборок
n = len(df)
train_size = int(n * 0.75)
val_size = int(n * 0.125)
test_size = n - train_size - val_size

X_train1, y_train1 = X1[:train_size], y1[:train_size]
X_val1, y_val1 = X1[train_size:train_size + val_size], y1[train_size:train_size + val_size]
X_test1, y_test1 = X1[train_size + val_size:], y1[train_size + val_size:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((13140, 56, 1), (13140,), (2190, 56, 1), (2190,), (2135, 56, 1), (2135,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, 1)))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(32))
model2.add(Dropout(0.5))
model2.add(Dense(16, activation='relu'))
model2.add(Dense(8, activation='relu'))
model2.add(Dense(1, activation='relu'))
model2.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                        │ (None, 56, 64)              │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 56, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_7 (LSTM)                        │ (None, 56, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 56, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_8 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 63,009 (246.13 KB)
#  Trainable params: 63,009 (246.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Настройки обратного вызова и компиляции модели
model_save_path = 'model2/model2-DEW_POINT.keras'
cp2 = ModelCheckpoint(model_save_path, save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
# Обучение модели
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 74s 134ms/step - loss: 12.6062 - root_mean_squared_error: 3.5416 - val_loss: 17.2345 - val_root_mean_squared_error: 4.1514
# Epoch 2/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 48s 115ms/step - loss: 7.6322 - root_mean_squared_error: 2.7574 - val_loss: 12.0616 - val_root_mean_squared_error: 3.4730
# Epoch 3/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 51s 125ms/step - loss: 5.7241 - root_mean_squared_error: 2.3919 - val_loss: 9.8551 - val_root_mean_squared_error: 3.1393
# Epoch 4/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 55s 133ms/step - loss: 5.4812 - root_mean_squared_error: 2.3393 - val_loss: 8.7915 - val_root_mean_squared_error: 2.9650
# Epoch 5/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 44s 106ms/step - loss: 5.3609 - root_mean_squared_error: 2.3142 - val_loss: 7.9544 - val_root_mean_squared_error: 2.8204
# Epoch 6/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 4.6268 - root_mean_squared_error: 2.1494 - val_loss: 7.4571 - val_root_mean_squared_error: 2.7308
# Epoch 7/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 98ms/step - loss: 4.4743 - root_mean_squared_error: 2.1130 - val_loss: 7.1225 - val_root_mean_squared_error: 2.6688
# Epoch 8/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 4.2041 - root_mean_squared_error: 2.0469 - val_loss: 6.7985 - val_root_mean_squared_error: 2.6074
# Epoch 9/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 90ms/step - loss: 4.1091 - root_mean_squared_error: 2.0211 - val_loss: 6.5678 - val_root_mean_squared_error: 2.5628
# Epoch 10/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 93ms/step - loss: 3.9888 - root_mean_squared_error: 1.9949 - val_loss: 6.2994 - val_root_mean_squared_error: 2.5099
# Epoch 11/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - loss: 4.2312 - root_mean_squared_error: 2.0530 - val_loss: 6.1785 - val_root_mean_squared_error: 2.4857
# Epoch 12/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 4.1091 - root_mean_squared_error: 2.0256 - val_loss: 6.0943 - val_root_mean_squared_error: 2.4687
# Epoch 13/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 3.5395 - root_mean_squared_error: 1.8755 - val_loss: 6.1122 - val_root_mean_squared_error: 2.4723
# Epoch 14/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 92ms/step - loss: 3.7997 - root_mean_squared_error: 1.9486 - val_loss: 6.1145 - val_root_mean_squared_error: 2.4728
# Epoch 15/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 4.1430 - root_mean_squared_error: 2.0343 - val_loss: 6.0654 - val_root_mean_squared_error: 2.4628
# Epoch 16/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 4.0700 - root_mean_squared_error: 2.0160 - val_loss: 6.0078 - val_root_mean_squared_error: 2.4511
# Epoch 17/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 3.9288 - root_mean_squared_error: 1.9808 - val_loss: 5.9937 - val_root_mean_squared_error: 2.4482
# Epoch 18/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 96ms/step - loss: 3.7770 - root_mean_squared_error: 1.9429 - val_loss: 5.9781 - val_root_mean_squared_error: 2.4450
# Epoch 19/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 93ms/step - loss: 4.1631 - root_mean_squared_error: 2.0389 - val_loss: 5.9990 - val_root_mean_squared_error: 2.4493
# Epoch 20/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 41s 94ms/step - loss: 4.0549 - root_mean_squared_error: 2.0121 - val_loss: 5.9447 - val_root_mean_squared_error: 2.4382
# Epoch 21/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 3.9030 - root_mean_squared_error: 1.9736 - val_loss: 5.9853 - val_root_mean_squared_error: 2.4465
# Epoch 22/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 93ms/step - loss: 3.7051 - root_mean_squared_error: 1.9212 - val_loss: 6.0102 - val_root_mean_squared_error: 2.4516
# Epoch 23/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 3.8501 - root_mean_squared_error: 1.9614 - val_loss: 5.9564 - val_root_mean_squared_error: 2.4406
# Epoch 24/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 93ms/step - loss: 4.2224 - root_mean_squared_error: 2.0535 - val_loss: 5.9738 - val_root_mean_squared_error: 2.4441
# Epoch 25/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 96ms/step - loss: 3.5829 - root_mean_squared_error: 1.8890 - val_loss: 5.9835 - val_root_mean_squared_error: 2.4461
# Epoch 26/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 96ms/step - loss: 3.9096 - root_mean_squared_error: 1.9752 - val_loss: 5.9136 - val_root_mean_squared_error: 2.4318
# Epoch 27/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 3.8070 - root_mean_squared_error: 1.9504 - val_loss: 5.9357 - val_root_mean_squared_error: 2.4363
# Epoch 28/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 3.8010 - root_mean_squared_error: 1.9466 - val_loss: 5.9590 - val_root_mean_squared_error: 2.4411
# Epoch 29/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 3.6681 - root_mean_squared_error: 1.9122 - val_loss: 5.8957 - val_root_mean_squared_error: 2.4281
# Epoch 30/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 93ms/step - loss: 3.5027 - root_mean_squared_error: 1.8661 - val_loss: 5.9123 - val_root_mean_squared_error: 2.4315
# Epoch 31/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 4.0110 - root_mean_squared_error: 2.0019 - val_loss: 5.9495 - val_root_mean_squared_error: 2.4392
# Epoch 32/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 3.4235 - root_mean_squared_error: 1.8487 - val_loss: 5.8792 - val_root_mean_squared_error: 2.4247
# Epoch 33/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 96ms/step - loss: 3.8431 - root_mean_squared_error: 1.9595 - val_loss: 5.8609 - val_root_mean_squared_error: 2.4209
# Epoch 34/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 96ms/step - loss: 3.9713 - root_mean_squared_error: 1.9919 - val_loss: 5.8360 - val_root_mean_squared_error: 2.4158
# Epoch 35/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 3.7933 - root_mean_squared_error: 1.9471 - val_loss: 5.9174 - val_root_mean_squared_error: 2.4326
# Epoch 36/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 3.9184 - root_mean_squared_error: 1.9766 - val_loss: 6.0509 - val_root_mean_squared_error: 2.4599
# Epoch 37/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 3.6187 - root_mean_squared_error: 1.8997 - val_loss: 5.9442 - val_root_mean_squared_error: 2.4381
# Epoch 38/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 3.9493 - root_mean_squared_error: 1.9862 - val_loss: 5.8761 - val_root_mean_squared_error: 2.4241
# Epoch 39/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 96ms/step - loss: 4.1321 - root_mean_squared_error: 2.0304 - val_loss: 5.9251 - val_root_mean_squared_error: 2.4342
# Epoch 40/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 98ms/step - loss: 3.6970 - root_mean_squared_error: 1.9217 - val_loss: 5.8408 - val_root_mean_squared_error: 2.4168
# Epoch 41/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 42s 101ms/step - loss: 3.6864 - root_mean_squared_error: 1.9194 - val_loss: 6.1697 - val_root_mean_squared_error: 2.4839
# Epoch 42/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 34s 82ms/step - loss: 3.6727 - root_mean_squared_error: 1.9153 - val_loss: 5.9571 - val_root_mean_squared_error: 2.4407
# Epoch 43/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 3.7143 - root_mean_squared_error: 1.9258 - val_loss: 5.9861 - val_root_mean_squared_error: 2.4466
# Epoch 44/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 3.6856 - root_mean_squared_error: 1.9190 - val_loss: 5.9411 - val_root_mean_squared_error: 2.4374
# Epoch 45/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 3.8052 - root_mean_squared_error: 1.9467 - val_loss: 5.9068 - val_root_mean_squared_error: 2.4304
# Epoch 46/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - loss: 3.8202 - root_mean_squared_error: 1.9517 - val_loss: 6.0169 - val_root_mean_squared_error: 2.4529
# Epoch 47/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 3.9532 - root_mean_squared_error: 1.9830 - val_loss: 5.8218 - val_root_mean_squared_error: 2.4128
# Epoch 48/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - loss: 3.7776 - root_mean_squared_error: 1.9425 - val_loss: 5.9105 - val_root_mean_squared_error: 2.4312
# Epoch 49/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 96ms/step - loss: 3.4521 - root_mean_squared_error: 1.8544 - val_loss: 5.8177 - val_root_mean_squared_error: 2.4120
# Epoch 50/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 96ms/step - loss: 3.4151 - root_mean_squared_error: 1.8432 - val_loss: 5.8163 - val_root_mean_squared_error: 2.4117

# %%
# Сохранение всей модели на диск
model_save_path = 'model2/model2-DEW_POINT.keras' 
model2.save(model_save_path)
print(f"Модель сохранена в {model_save_path}")
# Out:
# Модель сохранена в model2/model2-DEW_POINT.keras

# %%
from keras.models import load_model
model = load_model('model2/model2-DEW_POINT.keras')

# %%
# Прогнозирование на тестовых данных
y_pred = model.predict(X_test1)

# Вывод предсказаний
print(y_pred)
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step
# [[12.952487]
#  [13.289248]
#  [13.883967]
#  ...
#  [16.11226 ]
#  [16.771664]
#  [16.81171 ]]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=6):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='3h')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, 1)
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append(prediction[0, 0])
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = temp.values[-WINDOW_SIZE:]
last_known_dates = temp.index[-WINDOW_SIZE:]

# Прогнозирование на 3 шага вперед
future_steps = 56
future_dates, predictions = predict_future(model, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2024-06-15 15:00:00: 16.523160934448242
# 2024-06-15 18:00:00: 15.758467674255371
# 2024-06-15 21:00:00: 15.832879066467285
# 2024-06-16 00:00:00: 15.908219337463379
# 2024-06-16 03:00:00: 15.86983585357666
# 2024-06-16 06:00:00: 15.817009925842285
# 2024-06-16 09:00:00: 15.776068687438965
# 2024-06-16 12:00:00: 15.740704536437988
# 2024-06-16 15:00:00: 15.707439422607422
# 2024-06-16 18:00:00: 15.676445960998535
# 2024-06-16 21:00:00: 15.648079872131348
# 2024-06-17 00:00:00: 15.62224292755127
# 2024-06-17 03:00:00: 15.59870433807373
# 2024-06-17 06:00:00: 15.577256202697754
# 2024-06-17 09:00:00: 15.557713508605957
# 2024-06-17 12:00:00: 15.539902687072754
# 2024-06-17 15:00:00: 15.523662567138672
# 2024-06-17 18:00:00: 15.508856773376465
# 2024-06-17 21:00:00: 15.495352745056152
# 2024-06-18 00:00:00: 15.483033180236816
# 2024-06-18 03:00:00: 15.471793174743652
# 2024-06-18 06:00:00: 15.461539268493652
# 2024-06-18 09:00:00: 15.452181816101074
# 2024-06-18 12:00:00: 15.443642616271973
# 2024-06-18 15:00:00: 15.435853958129883
# 2024-06-18 18:00:00: 15.428750038146973
# 2024-06-18 21:00:00: 15.422270774841309
# 2024-06-19 00:00:00: 15.416359901428223
# 2024-06-19 03:00:00: 15.410969734191895
# 2024-06-19 06:00:00: 15.406244277954102
# 2024-06-19 09:00:00: 15.401744842529297
# 2024-06-19 12:00:00: 15.397467613220215
# 2024-06-19 15:00:00: 15.393738746643066
# 2024-06-19 18:00:00: 15.390454292297363
# 2024-06-19 21:00:00: 15.387469291687012
# 2024-06-20 00:00:00: 15.384732246398926
# 2024-06-20 03:00:00: 15.382227897644043
# 2024-06-20 06:00:00: 15.380057334899902
# 2024-06-20 09:00:00: 15.378174781799316
# 2024-06-20 12:00:00: 15.376324653625488
# 2024-06-20 15:00:00: 15.374640464782715
# 2024-06-20 18:00:00: 15.3732271194458
# 2024-06-20 21:00:00: 15.372084617614746
# 2024-06-21 00:00:00: 15.370862007141113
# 2024-06-21 03:00:00: 15.36962604522705
# 2024-06-21 06:00:00: 15.368474006652832
# 2024-06-21 09:00:00: 15.367542266845703
# 2024-06-21 12:00:00: 15.366873741149902
# 2024-06-21 15:00:00: 15.366131782531738
# 2024-06-21 18:00:00: 15.365338325500488
# 2024-06-21 21:00:00: 15.364569664001465
# 2024-06-22 00:00:00: 15.363842964172363
# 2024-06-22 03:00:00: 15.363128662109375
# 2024-06-22 06:00:00: 15.362439155578613
# 2024-06-22 09:00:00: 15.361821174621582
# 2024-06-22 12:00:00: 15.36129093170166

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[700:900], label='Предсказанные значения', color='blue')
plt.plot(y_test1[700:900], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step

# %%
# Оценка MAE
mae = mean_absolute_error(y_test1, y_pred1)

# Оценка MSE
mse = mean_squared_error(y_test1, y_pred1)

# Оценка RMSE
rmse = np.sqrt(mse)

# Оценка R^2
r2 = r2_score(y_test1, y_pred1)

print("Средняя абсолютная ошибка (MAE):", mae)
print("Средняя квадратичная ошибка (MSE):", mse)
print("Корень из среднеквадратичной ошибки (RMSE):", rmse)
print("Коэффициент детерминации (R^2):", r2)
# Out:
# Средняя абсолютная ошибка (MAE): 1.2428512904673792
# Средняя квадратичная ошибка (MSE): 6.96826682935686
# Корень из среднеквадратичной ошибки (RMSE): 2.639747493484341
# Коэффициент детерминации (R^2): 0.7041651824686188
