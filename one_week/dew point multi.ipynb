# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# Загрузка данных
df = pd.read_csv("../meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

# Включение необходимых колонок
required_cols = ['DEW_POINT', 'HC_RELATIVE_HUMIDITY', 'LEAF_WETNESS', 'PRECIPITATION', 'HC_AIR_TEMPERATURE', 'WIND_SPEED', 'SOLAR_RADIATION']
df = df[required_cols]
df = df.resample('3h').mean()

# Нормализация данных
scaler = MinMaxScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index)

# Визуализация данных
plt.figure(figsize=(10, 6))
plt.plot(scaled_df['DEW_POINT'], label='Точка росы (нормализованная)', color='blue')
plt.ylabel('Значение (нормализованное)')
plt.legend()
plt.show()

# Функция для преобразования данных в X и y
def df_to_X_y(df, window_size=24):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        X.append(df_as_np[i:i + window_size])
        y.append(df_as_np[i + window_size][0])  # Целевой признак - 'DEW_POINT'
    return np.array(X), np.array(y)

WINDOW_SIZE = 56
X, y = df_to_X_y(scaled_df, WINDOW_SIZE)

# Разделение данных на обучающую, валидационную и тестовую выборки
n = len(scaled_df)
train_size = int(n * 0.75)
val_size = int(n * 0.125)
test_size = n - train_size - val_size

X_train, y_train = X[:train_size], y[:train_size]
X_val, y_val = X[train_size:train_size + val_size], y[train_size:train_size + val_size]
X_test, y_test = X[train_size + val_size:], y[train_size + val_size:]

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape)
# Out:
# (13140, 56, 7) (13140,) (2190, 56, 7) (2190,) (2135, 56, 7) (2135,)

# %%
# Определение модели
model = Sequential()
model.add(InputLayer((WINDOW_SIZE, len(required_cols))))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(32))
model.add(Dropout(0.5))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='relu'))
model.summary()

# Настройки обратного вызова и компиляции модели
model_save_path = 'model2/model2-DEW_POINT.keras'
cp = ModelCheckpoint(model_save_path, save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 56, 64)              │          18,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 56, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 56, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 56, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 64,545 (252.13 KB)
#  Trainable params: 64,545 (252.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Обучение модели
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, callbacks=[cp])

# Сохранение модели
model_save_path = 'model2/model2-DEW_POINT.keras'
model.save(model_save_path)
print(f"Модель сохранена в {model_save_path}")
# Out:
# Epoch 1/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - loss: 0.0152 - root_mean_squared_error: 0.1203 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 2/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 29s 71ms/step - loss: 0.0066 - root_mean_squared_error: 0.0811 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 3/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 29s 71ms/step - loss: 0.0053 - root_mean_squared_error: 0.0726 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0920
# Epoch 4/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 28s 68ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0904
# Epoch 5/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 29s 70ms/step - loss: 0.0046 - root_mean_squared_error: 0.0677 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0855
# Epoch 6/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 28s 67ms/step - loss: 0.0043 - root_mean_squared_error: 0.0652 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0853
# Epoch 7/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 28s 68ms/step - loss: 0.0040 - root_mean_squared_error: 0.0632 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 8/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 28s 68ms/step - loss: 0.0039 - root_mean_squared_error: 0.0626 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 9/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 29s 71ms/step - loss: 0.0038 - root_mean_squared_error: 0.0619 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0798
# Epoch 10/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 35s 85ms/step - loss: 0.0036 - root_mean_squared_error: 0.0603 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0842
# Epoch 11/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 0.0038 - root_mean_squared_error: 0.0613 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0846
# Epoch 12/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 36s 87ms/step - loss: 0.0038 - root_mean_squared_error: 0.0619 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0790
# Epoch 13/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 91ms/step - loss: 0.0034 - root_mean_squared_error: 0.0580 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0772
# Epoch 14/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 98ms/step - loss: 0.0035 - root_mean_squared_error: 0.0595 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0766
# Epoch 15/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 90ms/step - loss: 0.0034 - root_mean_squared_error: 0.0584 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0761
# Epoch 16/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 90ms/step - loss: 0.0035 - root_mean_squared_error: 0.0591 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0757
# Epoch 17/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 0.0035 - root_mean_squared_error: 0.0588 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0740
# Epoch 18/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 89ms/step - loss: 0.0035 - root_mean_squared_error: 0.0593 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0761
# Epoch 19/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 90ms/step - loss: 0.0035 - root_mean_squared_error: 0.0595 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0734
# Epoch 20/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 90ms/step - loss: 0.0035 - root_mean_squared_error: 0.0588 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0741
# Epoch 21/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 90ms/step - loss: 0.0034 - root_mean_squared_error: 0.0584 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0793
# Epoch 22/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 43s 96ms/step - loss: 0.0029 - root_mean_squared_error: 0.0538 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0740
# Epoch 23/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 89ms/step - loss: 0.0032 - root_mean_squared_error: 0.0568 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 24/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 90ms/step - loss: 0.0032 - root_mean_squared_error: 0.0564 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0728
# Epoch 25/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 89ms/step - loss: 0.0030 - root_mean_squared_error: 0.0547 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0718
# Epoch 26/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 92ms/step - loss: 0.0031 - root_mean_squared_error: 0.0555 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0738
# Epoch 27/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 36s 88ms/step - loss: 0.0033 - root_mean_squared_error: 0.0575 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0758
# Epoch 28/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 92ms/step - loss: 0.0032 - root_mean_squared_error: 0.0564 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0711
# Epoch 29/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 92ms/step - loss: 0.0032 - root_mean_squared_error: 0.0568 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0714
# Epoch 30/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 91ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0722
# Epoch 31/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 90ms/step - loss: 0.0030 - root_mean_squared_error: 0.0545 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 32/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 38s 92ms/step - loss: 0.0030 - root_mean_squared_error: 0.0546 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 33/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 37s 90ms/step - loss: 0.0030 - root_mean_squared_error: 0.0548 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 34/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 42s 102ms/step - loss: 0.0030 - root_mean_squared_error: 0.0547 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0696
# Epoch 35/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 47s 114ms/step - loss: 0.0028 - root_mean_squared_error: 0.0527 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 36/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 43s 105ms/step - loss: 0.0028 - root_mean_squared_error: 0.0527 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 37/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 45s 109ms/step - loss: 0.0029 - root_mean_squared_error: 0.0538 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0680
# Epoch 38/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 42s 103ms/step - loss: 0.0028 - root_mean_squared_error: 0.0533 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0677
# Epoch 39/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 50s 121ms/step - loss: 0.0028 - root_mean_squared_error: 0.0526 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0689
# Epoch 42/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 43s 105ms/step - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 43/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 97ms/step - loss: 0.0028 - root_mean_squared_error: 0.0524 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 44/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 42s 103ms/step - loss: 0.0028 - root_mean_squared_error: 0.0528 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0662
# Epoch 45/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - loss: 0.0025 - root_mean_squared_error: 0.0500 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0677
# Epoch 46/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 47/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0657
# Epoch 48/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 40s 97ms/step - loss: 0.0025 - root_mean_squared_error: 0.0497 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 49/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 52s 126ms/step - loss: 0.0025 - root_mean_squared_error: 0.0496 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0682
# Epoch 50/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 50s 121ms/step - loss: 0.0027 - root_mean_squared_error: 0.0521 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653
# Модель сохранена в model2/model2-DEW_POINT.keras

# %%
# Загрузка модели
model = tf.keras.models.load_model(model_save_path)

# Прогнозирование на тестовых данных
y_pred = model.predict(X_test)

# Обратная трансформация предсказанных данных
y_test_inverse = scaler.inverse_transform(np.concatenate([y_test.reshape(-1, 1), np.zeros((len(y_test), len(required_cols) - 1))], axis=1))[:, 0]
y_pred_inverse = scaler.inverse_transform(np.concatenate([y_pred, np.zeros((len(y_pred), len(required_cols) - 1))], axis=1))[:, 0]

# Вывод предсказаний
print(y_pred_inverse)
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step
# [11.69080682 10.95727676 10.99835211 ... 13.29137144 14.60536945
#  14.96101712]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=56):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='3h')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, len(required_cols))
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append([prediction[0, 0]] + [0] * (len(required_cols) - 1))  # Добавляем 0 для остальных признаков
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = scaled_df.values[-WINDOW_SIZE:]
last_known_dates = scaled_df.index[-WINDOW_SIZE:]

# Прогнозирование на 56 шагов вперед
future_steps = 56
future_dates, predictions = predict_future(model, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Обратная трансформация предсказанных данных для будущего
predictions_inverse = scaler.inverse_transform(np.concatenate([np.array(predictions).reshape(-1, 1), np.zeros((len(predictions), len(required_cols) - 1))], axis=1))[:, 0]

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions_inverse):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 2024-06-15 15:00:00: 14.476193485657372
# 2024-06-15 18:00:00: 11.289613560835518
# 2024-06-15 21:00:00: 8.259369776646295
# 2024-06-16 00:00:00: 5.91109568576018
# 2024-06-16 03:00:00: 4.375307608644167
# 2024-06-16 06:00:00: 3.3299712071816123
# 2024-06-16 09:00:00: 2.5121117691198984
# 2024-06-16 12:00:00: 1.7644347290198006
# 2024-06-16 15:00:00: 1.2279102037350336
# 2024-06-16 18:00:00: 0.729951467613379
