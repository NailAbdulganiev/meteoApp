# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

df = pd.read_csv("../meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

required_cols = ['DEW_POINT']
df = df[required_cols]
df = df.resample('3h').mean()
temp = df['DEW_POINT']

plt.figure(figsize=(10, 6))
plt.plot(df['DEW_POINT'], label='Точка росы', color='blue')

# Настройка графика
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# предсказание, основанное не предыдущем суточном дне
def df_to_X_y(df, window_size=24):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE = 24
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)

# Размеры выборок
n = len(df)
train_size = int(n * 0.75)
val_size = int(n * 0.125)
test_size = n - train_size - val_size

X_train1, y_train1 = X1[:train_size], y1[:train_size]
X_val1, y_val1 = X1[train_size:train_size + val_size], y1[train_size:train_size + val_size]
X_test1, y_test1 = X1[train_size + val_size:], y1[train_size + val_size:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((13140, 24, 1), (13140,), (2190, 24, 1), (2190,), (2167, 24, 1), (2167,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, 1)))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(32))
model2.add(Dropout(0.5))
model2.add(Dense(16, activation='relu'))
model2.add(Dense(8, activation='relu'))
model2.add(Dense(1, activation='relu'))
model2.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                        │ (None, 24, 64)              │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 24, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_7 (LSTM)                        │ (None, 24, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 24, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_8 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 63,009 (246.13 KB)
#  Trainable params: 63,009 (246.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Настройки обратного вызова и компиляции модели
model_save_path = 'model2/model2-DEW_POINT.keras'
cp2 = ModelCheckpoint(model_save_path, save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
# Обучение модели
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 30s 45ms/step - loss: 13.7634 - root_mean_squared_error: 3.7016 - val_loss: 17.6913 - val_root_mean_squared_error: 4.2061
# Epoch 2/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - loss: 8.1531 - root_mean_squared_error: 2.8482 - val_loss: 12.3483 - val_root_mean_squared_error: 3.5140
# Epoch 3/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 18s 43ms/step - loss: 6.0155 - root_mean_squared_error: 2.4510 - val_loss: 9.8703 - val_root_mean_squared_error: 3.1417
# Epoch 4/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 18s 44ms/step - loss: 5.4248 - root_mean_squared_error: 2.3277 - val_loss: 8.6138 - val_root_mean_squared_error: 2.9349
# Epoch 5/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 18s 43ms/step - loss: 4.9942 - root_mean_squared_error: 2.2341 - val_loss: 7.9089 - val_root_mean_squared_error: 2.8123
# Epoch 6/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - loss: 4.7143 - root_mean_squared_error: 2.1708 - val_loss: 7.3437 - val_root_mean_squared_error: 2.7099
# Epoch 7/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 18s 44ms/step - loss: 4.4308 - root_mean_squared_error: 2.1039 - val_loss: 6.9533 - val_root_mean_squared_error: 2.6369
# Epoch 8/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 18s 43ms/step - loss: 4.3867 - root_mean_squared_error: 2.0930 - val_loss: 6.6555 - val_root_mean_squared_error: 2.5798
# Epoch 9/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 18s 44ms/step - loss: 4.1937 - root_mean_squared_error: 2.0470 - val_loss: 6.4279 - val_root_mean_squared_error: 2.5353
# Epoch 10/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 18s 43ms/step - loss: 4.0910 - root_mean_squared_error: 2.0206 - val_loss: 6.4516 - val_root_mean_squared_error: 2.5400
# Epoch 11/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - loss: 4.2050 - root_mean_squared_error: 2.0492 - val_loss: 6.2850 - val_root_mean_squared_error: 2.5070
# Epoch 12/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 3.9739 - root_mean_squared_error: 1.9924 - val_loss: 6.3031 - val_root_mean_squared_error: 2.5106
# Epoch 13/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - loss: 3.9406 - root_mean_squared_error: 1.9831 - val_loss: 6.2026 - val_root_mean_squared_error: 2.4905
# Epoch 14/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 16s 38ms/step - loss: 4.3375 - root_mean_squared_error: 2.0795 - val_loss: 6.1722 - val_root_mean_squared_error: 2.4844
# Epoch 15/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - loss: 4.0334 - root_mean_squared_error: 2.0078 - val_loss: 6.0992 - val_root_mean_squared_error: 2.4697
# Epoch 16/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - loss: 3.8977 - root_mean_squared_error: 1.9715 - val_loss: 6.1195 - val_root_mean_squared_error: 2.4738
# Epoch 17/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 16s 39ms/step - loss: 3.5328 - root_mean_squared_error: 1.8761 - val_loss: 6.0917 - val_root_mean_squared_error: 2.4681
# Epoch 18/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 19s 35ms/step - loss: 3.9737 - root_mean_squared_error: 1.9916 - val_loss: 6.2255 - val_root_mean_squared_error: 2.4951
# Epoch 19/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - loss: 3.7823 - root_mean_squared_error: 1.9420 - val_loss: 6.1203 - val_root_mean_squared_error: 2.4739
# Epoch 20/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 4.0182 - root_mean_squared_error: 2.0026 - val_loss: 6.0296 - val_root_mean_squared_error: 2.4555
# Epoch 21/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - loss: 3.7998 - root_mean_squared_error: 1.9482 - val_loss: 5.9944 - val_root_mean_squared_error: 2.4483
# Epoch 22/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 3.8397 - root_mean_squared_error: 1.9562 - val_loss: 5.9963 - val_root_mean_squared_error: 2.4487
# Epoch 23/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - loss: 4.0547 - root_mean_squared_error: 2.0111 - val_loss: 5.9630 - val_root_mean_squared_error: 2.4419
# Epoch 24/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 4.0915 - root_mean_squared_error: 2.0167 - val_loss: 5.9418 - val_root_mean_squared_error: 2.4376
# Epoch 25/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - loss: 3.8126 - root_mean_squared_error: 1.9500 - val_loss: 5.9362 - val_root_mean_squared_error: 2.4364
# Epoch 26/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - loss: 3.7577 - root_mean_squared_error: 1.9377 - val_loss: 5.9251 - val_root_mean_squared_error: 2.4341
# Epoch 27/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 3.8776 - root_mean_squared_error: 1.9686 - val_loss: 5.9465 - val_root_mean_squared_error: 2.4385
# Epoch 28/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - loss: 3.7644 - root_mean_squared_error: 1.9389 - val_loss: 5.9226 - val_root_mean_squared_error: 2.4336
# Epoch 29/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - loss: 3.8520 - root_mean_squared_error: 1.9563 - val_loss: 5.8937 - val_root_mean_squared_error: 2.4277
# Epoch 30/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - loss: 3.7404 - root_mean_squared_error: 1.9332 - val_loss: 5.8780 - val_root_mean_squared_error: 2.4245
# Epoch 31/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - loss: 3.5070 - root_mean_squared_error: 1.8714 - val_loss: 5.8867 - val_root_mean_squared_error: 2.4263
# Epoch 32/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 15s 38ms/step - loss: 3.6570 - root_mean_squared_error: 1.9091 - val_loss: 5.9614 - val_root_mean_squared_error: 2.4416
# Epoch 33/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - loss: 3.8333 - root_mean_squared_error: 1.9571 - val_loss: 5.8195 - val_root_mean_squared_error: 2.4124
# Epoch 34/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - loss: 4.1151 - root_mean_squared_error: 2.0260 - val_loss: 5.8449 - val_root_mean_squared_error: 2.4176
# Epoch 35/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step - loss: 3.7837 - root_mean_squared_error: 1.9407 - val_loss: 5.8494 - val_root_mean_squared_error: 2.4185
# Epoch 36/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - loss: 3.7436 - root_mean_squared_error: 1.9341 - val_loss: 5.8771 - val_root_mean_squared_error: 2.4243
# Epoch 37/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - loss: 3.6807 - root_mean_squared_error: 1.9169 - val_loss: 5.8212 - val_root_mean_squared_error: 2.4127
# Epoch 38/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - loss: 3.7173 - root_mean_squared_error: 1.9268 - val_loss: 5.8023 - val_root_mean_squared_error: 2.4088
# Epoch 39/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - loss: 3.8158 - root_mean_squared_error: 1.9518 - val_loss: 5.8896 - val_root_mean_squared_error: 2.4269
# Epoch 40/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 16s 39ms/step - loss: 3.6492 - root_mean_squared_error: 1.9091 - val_loss: 5.8123 - val_root_mean_squared_error: 2.4109
# Epoch 41/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step - loss: 3.6073 - root_mean_squared_error: 1.8972 - val_loss: 5.8720 - val_root_mean_squared_error: 2.4232
# Epoch 42/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step - loss: 3.4874 - root_mean_squared_error: 1.8638 - val_loss: 5.8424 - val_root_mean_squared_error: 2.4171
# Epoch 43/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 16s 39ms/step - loss: 4.0133 - root_mean_squared_error: 1.9923 - val_loss: 5.8568 - val_root_mean_squared_error: 2.4201
# Epoch 44/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 16s 40ms/step - loss: 3.7578 - root_mean_squared_error: 1.9366 - val_loss: 5.8328 - val_root_mean_squared_error: 2.4151
# Epoch 45/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - loss: 3.7588 - root_mean_squared_error: 1.9371 - val_loss: 5.9299 - val_root_mean_squared_error: 2.4351
# Epoch 46/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 16s 39ms/step - loss: 3.5851 - root_mean_squared_error: 1.8917 - val_loss: 5.8410 - val_root_mean_squared_error: 2.4168
# Epoch 47/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - loss: 3.5246 - root_mean_squared_error: 1.8749 - val_loss: 5.8689 - val_root_mean_squared_error: 2.4226
# Epoch 48/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step - loss: 3.6773 - root_mean_squared_error: 1.9159 - val_loss: 5.8121 - val_root_mean_squared_error: 2.4108
# Epoch 49/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - loss: 3.6598 - root_mean_squared_error: 1.9099 - val_loss: 5.8374 - val_root_mean_squared_error: 2.4161
# Epoch 50/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - loss: 3.6080 - root_mean_squared_error: 1.8963 - val_loss: 5.8662 - val_root_mean_squared_error: 2.4220

# %%
# Сохранение всей модели на диск
model_save_path = 'model2/model2-DEW_POINT.keras' 
model2.save(model_save_path)
print(f"Модель сохранена в {model_save_path}")
# Out:
# Модель сохранена в model2/model2-DEW_POINT.keras

# %%
from keras.models import load_model
model = load_model('model2/model2-DEW_POINT.keras')

# %%
# Прогнозирование на тестовых данных
y_pred = model.predict(X_test1)

# Вывод предсказаний
print(y_pred)
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step
# [[ 8.707888 ]
#  [ 6.07669  ]
#  [ 7.5750346]
#  ...
#  [15.871061 ]
#  [16.598837 ]
#  [16.54397  ]]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=6):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='3h')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, 1)
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append(prediction[0, 0])
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = temp.values[-WINDOW_SIZE:]
last_known_dates = temp.index[-WINDOW_SIZE:]

# Прогнозирование на 3 шага вперед
future_steps = 24
future_dates, predictions = predict_future(model, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 2024-06-15 15:00:00: 16.180755615234375
# 2024-06-15 18:00:00: 14.996269226074219
# 2024-06-15 21:00:00: 15.05285358428955
# 2024-06-16 00:00:00: 15.254140853881836
# 2024-06-16 03:00:00: 15.241762161254883
# 2024-06-16 06:00:00: 15.173361778259277
# 2024-06-16 09:00:00: 15.14463996887207
# 2024-06-16 12:00:00: 15.114917755126953
# 2024-06-16 15:00:00: 15.0988130569458
# 2024-06-16 18:00:00: 15.073505401611328
# 2024-06-16 21:00:00: 14.994991302490234
# 2024-06-17 00:00:00: 14.925325393676758
# 2024-06-17 03:00:00: 14.882000923156738
# 2024-06-17 06:00:00: 14.84920597076416
# 2024-06-17 09:00:00: 14.8043794631958
# 2024-06-17 12:00:00: 14.797707557678223
# 2024-06-17 15:00:00: 14.79876708984375
# 2024-06-17 18:00:00: 14.790162086486816
# 2024-06-17 21:00:00: 14.774503707885742
# 2024-06-18 00:00:00: 14.758544921875
# 2024-06-18 03:00:00: 14.743724822998047
# 2024-06-18 06:00:00: 14.725970268249512
# 2024-06-18 09:00:00: 14.698980331420898
# 2024-06-18 12:00:00: 14.66709041595459

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[700:900], label='Предсказанные значения', color='blue')
plt.plot(y_test1[700:900], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step

# %%
# Оценка MAE
mae = mean_absolute_error(y_test1, y_pred1)

# Оценка MSE
mse = mean_squared_error(y_test1, y_pred1)

# Оценка RMSE
rmse = np.sqrt(mse)

# Оценка R^2
r2 = r2_score(y_test1, y_pred1)

print("Средняя абсолютная ошибка (MAE):", mae)
print("Средняя квадратичная ошибка (MSE):", mse)
print("Корень из среднеквадратичной ошибки (RMSE):", rmse)
print("Коэффициент детерминации (R^2):", r2)
# Out:
# Средняя абсолютная ошибка (MAE): 1.2422375062622393
# Средняя квадратичная ошибка (MSE): 6.894687476604273
# Корень из среднеквадратичной ошибки (RMSE): 2.6257736910488445
# Коэффициент детерминации (R^2): 0.7161327710179588
