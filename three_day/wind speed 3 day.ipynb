# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

df = pd.read_csv("../meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

required_cols = ['WIND_SPEED']
df = df[required_cols]
df = df.resample('3h').mean()
temp = df['WIND_SPEED']

plt.figure(figsize=(10, 6))
plt.plot(df['WIND_SPEED'], label='Скорость ветра', color='blue')

# Настройка графика
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# предсказание, основанное не предыдущем суточном дне
def df_to_X_y(df, window_size=24):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE = 12
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)

# Размеры выборок
n = len(df)
train_size = int(n * 0.75)
val_size = int(n * 0.125)
test_size = n - train_size - val_size

X_train1, y_train1 = X1[:train_size], y1[:train_size]
X_val1, y_val1 = X1[train_size:train_size + val_size], y1[train_size:train_size + val_size]
X_test1, y_test1 = X1[train_size + val_size:], y1[train_size + val_size:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((13140, 12, 1), (13140,), (2190, 12, 1), (2190,), (2179, 12, 1), (2179,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, 1)))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(32))
model2.add(Dropout(0.5))
model2.add(Dense(16, activation='relu'))
model2.add(Dense(8, activation='relu'))
model2.add(Dense(1, activation='relu'))
model2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 12, 64)              │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 12, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 12, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 63,009 (246.13 KB)
#  Trainable params: 63,009 (246.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Настройки обратного вызова и компиляции модели
model_save_path = 'model2/model2-WIND_SPEED.keras'
cp2 = ModelCheckpoint(model_save_path, save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
# Обучение модели
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 24s 28ms/step - loss: 3.9032 - root_mean_squared_error: 1.9675 - val_loss: 1.5387 - val_root_mean_squared_error: 1.2404
# Epoch 2/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 2.0969 - root_mean_squared_error: 1.4478 - val_loss: 1.2653 - val_root_mean_squared_error: 1.1249
# Epoch 3/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - loss: 1.8171 - root_mean_squared_error: 1.3479 - val_loss: 1.1960 - val_root_mean_squared_error: 1.0936
# Epoch 4/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 1.6588 - root_mean_squared_error: 1.2877 - val_loss: 1.1083 - val_root_mean_squared_error: 1.0528
# Epoch 5/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 1.5608 - root_mean_squared_error: 1.2492 - val_loss: 1.0093 - val_root_mean_squared_error: 1.0046
# Epoch 6/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - loss: 1.4146 - root_mean_squared_error: 1.1893 - val_loss: 0.8522 - val_root_mean_squared_error: 0.9232
# Epoch 7/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 20s 25ms/step - loss: 1.2691 - root_mean_squared_error: 1.1264 - val_loss: 0.6957 - val_root_mean_squared_error: 0.8341
# Epoch 8/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.1644 - root_mean_squared_error: 1.0790 - val_loss: 0.6003 - val_root_mean_squared_error: 0.7748
# Epoch 9/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.0478 - root_mean_squared_error: 1.0236 - val_loss: 0.5690 - val_root_mean_squared_error: 0.7544
# Epoch 10/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - loss: 1.0052 - root_mean_squared_error: 1.0024 - val_loss: 0.5424 - val_root_mean_squared_error: 0.7365
# Epoch 11/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - loss: 1.0416 - root_mean_squared_error: 1.0196 - val_loss: 0.5395 - val_root_mean_squared_error: 0.7345
# Epoch 12/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - loss: 0.9591 - root_mean_squared_error: 0.9793 - val_loss: 0.5354 - val_root_mean_squared_error: 0.7317
# Epoch 13/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - loss: 0.9508 - root_mean_squared_error: 0.9749 - val_loss: 0.5190 - val_root_mean_squared_error: 0.7204
# Epoch 14/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - loss: 0.9352 - root_mean_squared_error: 0.9670 - val_loss: 0.5164 - val_root_mean_squared_error: 0.7186
# Epoch 15/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - loss: 0.9191 - root_mean_squared_error: 0.9586 - val_loss: 0.5121 - val_root_mean_squared_error: 0.7156
# Epoch 16/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - loss: 0.9276 - root_mean_squared_error: 0.9628 - val_loss: 0.5164 - val_root_mean_squared_error: 0.7186
# Epoch 17/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - loss: 0.8827 - root_mean_squared_error: 0.9393 - val_loss: 0.5174 - val_root_mean_squared_error: 0.7193
# Epoch 18/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - loss: 0.9003 - root_mean_squared_error: 0.9486 - val_loss: 0.5088 - val_root_mean_squared_error: 0.7133
# Epoch 19/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - loss: 0.9053 - root_mean_squared_error: 0.9514 - val_loss: 0.5079 - val_root_mean_squared_error: 0.7127
# Epoch 20/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - loss: 0.8791 - root_mean_squared_error: 0.9374 - val_loss: 0.5137 - val_root_mean_squared_error: 0.7168
# Epoch 21/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - loss: 0.8907 - root_mean_squared_error: 0.9437 - val_loss: 0.5082 - val_root_mean_squared_error: 0.7129
# Epoch 22/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.8643 - root_mean_squared_error: 0.9296 - val_loss: 0.5056 - val_root_mean_squared_error: 0.7111
# Epoch 23/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 0.8691 - root_mean_squared_error: 0.9322 - val_loss: 0.5059 - val_root_mean_squared_error: 0.7113
# Epoch 24/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - loss: 0.8376 - root_mean_squared_error: 0.9150 - val_loss: 0.5028 - val_root_mean_squared_error: 0.7091
# Epoch 25/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - loss: 0.8576 - root_mean_squared_error: 0.9259 - val_loss: 0.5095 - val_root_mean_squared_error: 0.7138
# Epoch 26/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - loss: 0.8303 - root_mean_squared_error: 0.9109 - val_loss: 0.5061 - val_root_mean_squared_error: 0.7114
# Epoch 27/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.8132 - root_mean_squared_error: 0.9015 - val_loss: 0.5081 - val_root_mean_squared_error: 0.7128
# Epoch 28/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.8187 - root_mean_squared_error: 0.9047 - val_loss: 0.5047 - val_root_mean_squared_error: 0.7104
# Epoch 29/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.8794 - root_mean_squared_error: 0.9375 - val_loss: 0.5042 - val_root_mean_squared_error: 0.7101
# Epoch 30/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.8234 - root_mean_squared_error: 0.9071 - val_loss: 0.5008 - val_root_mean_squared_error: 0.7077
# Epoch 31/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.8168 - root_mean_squared_error: 0.9036 - val_loss: 0.5039 - val_root_mean_squared_error: 0.7098
# Epoch 32/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.8160 - root_mean_squared_error: 0.9033 - val_loss: 0.5010 - val_root_mean_squared_error: 0.7078
# Epoch 33/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.8261 - root_mean_squared_error: 0.9087 - val_loss: 0.4985 - val_root_mean_squared_error: 0.7060
# Epoch 34/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.8328 - root_mean_squared_error: 0.9124 - val_loss: 0.5030 - val_root_mean_squared_error: 0.7092
# Epoch 35/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.8363 - root_mean_squared_error: 0.9143 - val_loss: 0.4970 - val_root_mean_squared_error: 0.7050
# Epoch 36/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.8119 - root_mean_squared_error: 0.9008 - val_loss: 0.4976 - val_root_mean_squared_error: 0.7054
# Epoch 37/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.8157 - root_mean_squared_error: 0.9030 - val_loss: 0.4965 - val_root_mean_squared_error: 0.7047
# Epoch 38/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.8299 - root_mean_squared_error: 0.9105 - val_loss: 0.4989 - val_root_mean_squared_error: 0.7063
# Epoch 39/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.8305 - root_mean_squared_error: 0.9112 - val_loss: 0.4962 - val_root_mean_squared_error: 0.7044
# Epoch 40/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - loss: 0.8224 - root_mean_squared_error: 0.9068 - val_loss: 0.5030 - val_root_mean_squared_error: 0.7092
# Epoch 41/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - loss: 0.7911 - root_mean_squared_error: 0.8893 - val_loss: 0.4948 - val_root_mean_squared_error: 0.7034
# Epoch 42/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - loss: 0.8248 - root_mean_squared_error: 0.9080 - val_loss: 0.4967 - val_root_mean_squared_error: 0.7048
# Epoch 43/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.8090 - root_mean_squared_error: 0.8992 - val_loss: 0.5125 - val_root_mean_squared_error: 0.7159
# Epoch 44/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - loss: 0.8032 - root_mean_squared_error: 0.8961 - val_loss: 0.4973 - val_root_mean_squared_error: 0.7052
# Epoch 45/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - loss: 0.8059 - root_mean_squared_error: 0.8975 - val_loss: 0.4918 - val_root_mean_squared_error: 0.7013
# Epoch 46/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 0.8078 - root_mean_squared_error: 0.8984 - val_loss: 0.5010 - val_root_mean_squared_error: 0.7078
# Epoch 47/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - loss: 0.8227 - root_mean_squared_error: 0.9068 - val_loss: 0.4966 - val_root_mean_squared_error: 0.7047
# Epoch 48/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - loss: 0.8287 - root_mean_squared_error: 0.9101 - val_loss: 0.4938 - val_root_mean_squared_error: 0.7027
# Epoch 49/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - loss: 0.7931 - root_mean_squared_error: 0.8903 - val_loss: 0.4888 - val_root_mean_squared_error: 0.6992
# Epoch 50/50
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - loss: 0.8032 - root_mean_squared_error: 0.8961 - val_loss: 0.5058 - val_root_mean_squared_error: 0.7112

# %%
# Сохранение всей модели на диск
model_save_path = 'model2/model2-WIND_SPEED.keras'
model2.save(model_save_path)
print(f"Модель сохранена в {model_save_path}")
# Out:
# Модель сохранена в model2/model2-WIND_SPEED.keras

# %%
from keras.models import load_model
model = load_model('model2/model2-WIND_SPEED.keras')

# %%
# Прогнозирование на тестовых данных
y_pred = model.predict(X_test1)

# Вывод предсказаний
print(y_pred)
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step
# [[0.57602715]
#  [0.94678533]
#  [2.6226249 ]
#  ...
#  [0.3120718 ]
#  [0.7708188 ]
#  [0.88226724]]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=10):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='3h')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, 1)
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append(prediction[0, 0])
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = temp.values[-WINDOW_SIZE:]
last_known_dates = temp.index[-WINDOW_SIZE:]

# Прогнозирование на 3 шага вперед
future_steps = 24
future_dates, predictions = predict_future(model, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 2024-06-15 15:00:00: 0.5458900332450867
# 2024-06-15 18:00:00: 0.44628143310546875
# 2024-06-15 21:00:00: 0.4031142592430115
# 2024-06-16 00:00:00: 0.4455567002296448
# 2024-06-16 03:00:00: 0.5754318833351135
# 2024-06-16 06:00:00: 0.7365831732749939
# 2024-06-16 09:00:00: 0.8070497512817383
# 2024-06-16 12:00:00: 0.7274096608161926
# 2024-06-16 15:00:00: 0.5509946346282959
# 2024-06-16 18:00:00: 0.40639567375183105
# 2024-06-16 21:00:00: 0.3699288070201874
# 2024-06-17 00:00:00: 0.4116089642047882
# 2024-06-17 03:00:00: 0.46735578775405884
# 2024-06-17 06:00:00: 0.515485405921936
# 2024-06-17 09:00:00: 0.5036540031433105
# 2024-06-17 12:00:00: 0.4387891888618469
# 2024-06-17 15:00:00: 0.3773777484893799
# 2024-06-17 18:00:00: 0.34371912479400635
# 2024-06-17 21:00:00: 0.3466997742652893
# 2024-06-18 00:00:00: 0.3785746097564697
# 2024-06-18 03:00:00: 0.41839393973350525
# 2024-06-18 06:00:00: 0.44080883264541626
# 2024-06-18 09:00:00: 0.43480050563812256
# 2024-06-18 12:00:00: 0.4120676517486572

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[700:800], label='Предсказанные значения', color='blue')
plt.plot(y_test1[700:800], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step

# %%
# Оценка MAE
mae = mean_absolute_error(y_test1, y_pred1)

# Оценка MSE
mse = mean_squared_error(y_test1, y_pred1)

# Оценка RMSE
rmse = np.sqrt(mse)

# Оценка R^2
r2 = r2_score(y_test1, y_pred1)

print("Средняя абсолютная ошибка (MAE):", mae)
print("Средняя квадратичная ошибка (MSE):", mse)
print("Корень из среднеквадратичной ошибки (RMSE):", rmse)
print("Коэффициент детерминации (R^2):", r2)
# Out:
# Средняя абсолютная ошибка (MAE): 0.623496412285355
# Средняя квадратичная ошибка (MSE): 0.7207418073072039
# Корень из среднеквадратичной ошибки (RMSE): 0.8489651390411764
# Коэффициент детерминации (R^2): 0.7358794055099156
