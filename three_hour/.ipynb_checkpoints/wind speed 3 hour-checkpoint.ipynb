# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

df = pd.read_csv("../meteo_data.csv")
df.index = pd.to_datetime(df.DATE)
del df['DATE']

required_cols = ['WIND_SPEED']
df = df[required_cols]

temp = df['WIND_SPEED']

plt.figure(figsize=(10, 6))
plt.plot(df['WIND_SPEED'], label='Скорость ветра', color='blue')

# Настройка графика
plt.ylabel('Значение')
plt.legend()

# Показать график
plt.show()

# %%
# предсказание, основанное не предыдущем суточном дне
def df_to_X_y(df, window_size=5):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE = 5
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
print(X1.shape, y1.shape)

X_train1, y_train1 = X1[:10500], y1[:10500]
X_val1, y_val1 = X1[10500:12000], y1[10500:12000]
X_test1, y_test1 = X1[12000:], y1[12000:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# (13902, 5, 1) (13902,)
# ((10500, 5, 1), (10500,), (1500, 5, 1), (1500,), (1902, 5, 1), (1902,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, 1)))
model2.add(LSTM(64, return_sequences=True))
model2.add(Dropout(0.5))
model2.add(LSTM(32))
model2.add(Dropout(0.5))
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'relu'))
model2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 5, 64)               │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 5, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 8)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29,585 (115.57 KB)
#  Trainable params: 29,585 (115.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Настройки обратного вызова и компиляции модели
model_save_path = 'model2/model2-wind-speed.keras'
cp2 = ModelCheckpoint(model_save_path, save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
# Обучение модели
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp2])
# Out:
# Epoch 1/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 3.6422 - root_mean_squared_error: 1.8978 - val_loss: 1.0801 - val_root_mean_squared_error: 1.0399
# Epoch 2/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 1.0777 - root_mean_squared_error: 1.0378 - val_loss: 0.8034 - val_root_mean_squared_error: 0.8967
# Epoch 3/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.8899 - root_mean_squared_error: 0.9432 - val_loss: 0.6714 - val_root_mean_squared_error: 0.8196
# Epoch 4/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.7814 - root_mean_squared_error: 0.8839 - val_loss: 0.5752 - val_root_mean_squared_error: 0.7586
# Epoch 5/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.6832 - root_mean_squared_error: 0.8264 - val_loss: 0.5058 - val_root_mean_squared_error: 0.7113
# Epoch 6/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.6182 - root_mean_squared_error: 0.7862 - val_loss: 0.4732 - val_root_mean_squared_error: 0.6879
# Epoch 7/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5951 - root_mean_squared_error: 0.7713 - val_loss: 0.4580 - val_root_mean_squared_error: 0.6767
# Epoch 8/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5777 - root_mean_squared_error: 0.7598 - val_loss: 0.4378 - val_root_mean_squared_error: 0.6617
# Epoch 9/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5533 - root_mean_squared_error: 0.7436 - val_loss: 0.4232 - val_root_mean_squared_error: 0.6505
# Epoch 10/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5235 - root_mean_squared_error: 0.7231 - val_loss: 0.4126 - val_root_mean_squared_error: 0.6423
# Epoch 11/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5307 - root_mean_squared_error: 0.7284 - val_loss: 0.4025 - val_root_mean_squared_error: 0.6344
# Epoch 12/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5120 - root_mean_squared_error: 0.7153 - val_loss: 0.3977 - val_root_mean_squared_error: 0.6305
# Epoch 13/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4868 - root_mean_squared_error: 0.6976 - val_loss: 0.3935 - val_root_mean_squared_error: 0.6271
# Epoch 14/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4829 - root_mean_squared_error: 0.6946 - val_loss: 0.3894 - val_root_mean_squared_error: 0.6239
# Epoch 15/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4790 - root_mean_squared_error: 0.6919 - val_loss: 0.3891 - val_root_mean_squared_error: 0.6236
# Epoch 16/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4739 - root_mean_squared_error: 0.6883 - val_loss: 0.3675 - val_root_mean_squared_error: 0.6062
# Epoch 17/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4723 - root_mean_squared_error: 0.6872 - val_loss: 0.3694 - val_root_mean_squared_error: 0.6077
# Epoch 18/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4471 - root_mean_squared_error: 0.6686 - val_loss: 0.3512 - val_root_mean_squared_error: 0.5926
# Epoch 19/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4559 - root_mean_squared_error: 0.6751 - val_loss: 0.3486 - val_root_mean_squared_error: 0.5904
# Epoch 20/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4319 - root_mean_squared_error: 0.6570 - val_loss: 0.3474 - val_root_mean_squared_error: 0.5893
# Epoch 21/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4232 - root_mean_squared_error: 0.6504 - val_loss: 0.3340 - val_root_mean_squared_error: 0.5779
# Epoch 22/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.4263 - root_mean_squared_error: 0.6528 - val_loss: 0.3429 - val_root_mean_squared_error: 0.5855
# Epoch 23/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.4344 - root_mean_squared_error: 0.6588 - val_loss: 0.3565 - val_root_mean_squared_error: 0.5969
# Epoch 24/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4427 - root_mean_squared_error: 0.6650 - val_loss: 0.3364 - val_root_mean_squared_error: 0.5799
# Epoch 25/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4358 - root_mean_squared_error: 0.6601 - val_loss: 0.3302 - val_root_mean_squared_error: 0.5746
# Epoch 26/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4297 - root_mean_squared_error: 0.6553 - val_loss: 0.3494 - val_root_mean_squared_error: 0.5910
# Epoch 27/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4129 - root_mean_squared_error: 0.6425 - val_loss: 0.3349 - val_root_mean_squared_error: 0.5786
# Epoch 28/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4178 - root_mean_squared_error: 0.6463 - val_loss: 0.3391 - val_root_mean_squared_error: 0.5822
# Epoch 29/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4047 - root_mean_squared_error: 0.6361 - val_loss: 0.3462 - val_root_mean_squared_error: 0.5882
# Epoch 30/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4094 - root_mean_squared_error: 0.6398 - val_loss: 0.3380 - val_root_mean_squared_error: 0.5813
# Epoch 31/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3983 - root_mean_squared_error: 0.6310 - val_loss: 0.3372 - val_root_mean_squared_error: 0.5805
# Epoch 32/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4198 - root_mean_squared_error: 0.6477 - val_loss: 0.3386 - val_root_mean_squared_error: 0.5817
# Epoch 33/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4132 - root_mean_squared_error: 0.6427 - val_loss: 0.3434 - val_root_mean_squared_error: 0.5858
# Epoch 34/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3928 - root_mean_squared_error: 0.6267 - val_loss: 0.3384 - val_root_mean_squared_error: 0.5816
# Epoch 35/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4051 - root_mean_squared_error: 0.6364 - val_loss: 0.3386 - val_root_mean_squared_error: 0.5817
# Epoch 36/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3945 - root_mean_squared_error: 0.6279 - val_loss: 0.3450 - val_root_mean_squared_error: 0.5872
# Epoch 37/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3853 - root_mean_squared_error: 0.6206 - val_loss: 0.3391 - val_root_mean_squared_error: 0.5822
# Epoch 38/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4039 - root_mean_squared_error: 0.6355 - val_loss: 0.3387 - val_root_mean_squared_error: 0.5818
# Epoch 39/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3959 - root_mean_squared_error: 0.6292 - val_loss: 0.3359 - val_root_mean_squared_error: 0.5794
# Epoch 40/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3966 - root_mean_squared_error: 0.6297 - val_loss: 0.3358 - val_root_mean_squared_error: 0.5793
# Epoch 41/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3824 - root_mean_squared_error: 0.6182 - val_loss: 0.3739 - val_root_mean_squared_error: 0.6111
# Epoch 42/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3762 - root_mean_squared_error: 0.6132 - val_loss: 0.3219 - val_root_mean_squared_error: 0.5673
# Epoch 43/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3945 - root_mean_squared_error: 0.6280 - val_loss: 0.3409 - val_root_mean_squared_error: 0.5837
# Epoch 44/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3853 - root_mean_squared_error: 0.6207 - val_loss: 0.3327 - val_root_mean_squared_error: 0.5766
# Epoch 45/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3955 - root_mean_squared_error: 0.6288 - val_loss: 0.3345 - val_root_mean_squared_error: 0.5782
# Epoch 46/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3853 - root_mean_squared_error: 0.6206 - val_loss: 0.3427 - val_root_mean_squared_error: 0.5852
# Epoch 47/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3839 - root_mean_squared_error: 0.6192 - val_loss: 0.3263 - val_root_mean_squared_error: 0.5711
# Epoch 48/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3716 - root_mean_squared_error: 0.6095 - val_loss: 0.3316 - val_root_mean_squared_error: 0.5757
# Epoch 49/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3617 - root_mean_squared_error: 0.6006 - val_loss: 0.3400 - val_root_mean_squared_error: 0.5829
# Epoch 50/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3676 - root_mean_squared_error: 0.6063 - val_loss: 0.3377 - val_root_mean_squared_error: 0.5809

# %%
# Сохранение всей модели на диск
model_save_path = 'model2/model2-wind-speed.keras'
model2.save(model_save_path)
print(f"Модель сохранена в {model_save_path}")
# Out:
# Модель сохранена в model2/model2-wind-speed.keras

# %%
from keras.models import load_model
model = load_model('model2/model2-wind-speed.keras')

# %%
# Прогнозирование на тестовых данных
y_pred = model.predict(X_test1)

# Вывод предсказаний
print(y_pred)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# [[3.9440742]
#  [3.0582469]
#  [3.7266347]
#  ...
#  [6.251588 ]
#  [4.4292173]
#  [2.9992793]]

# %%
# Прогнозирование на будущее
def predict_future(model, last_known_data, last_known_dates, steps=3, window_size=3):
    predictions = []
    future_dates = pd.date_range(start=last_known_dates[-1], periods=steps + 1, freq='h')[1:]
    
    current_data = last_known_data.tolist()
    
    for _ in range(steps):
        input_data = np.array(current_data[-window_size:]).reshape(1, window_size, 1)
        prediction = model.predict(input_data)
        predictions.append(prediction[0, 0])
        current_data.append(prediction[0, 0])
    
    return future_dates, predictions

# Последние известные данные и даты
last_known_data = temp.values[-WINDOW_SIZE:]
last_known_dates = temp.index[-WINDOW_SIZE:]

# Прогнозирование на 3 шага вперед
future_steps = 3
future_dates, predictions = predict_future(model, last_known_data, last_known_dates, future_steps, WINDOW_SIZE)

# Вывод предсказаний с датами
for date, pred in zip(future_dates, predictions):
    print(f"{date}: {pred}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2024-05-25 22:00:00: 2.913376808166504
# 2024-05-25 23:00:00: 2.580965518951416
# 2024-05-26 00:00:00: 2.193446397781372

# %%
# Предсказание на тестовом наборе данных
y_pred1 = model.predict(X_test1)

# Построение графика предсказанных и реальных значений
plt.figure(figsize=(10, 6))
plt.plot(y_pred1[700:800], label='Предсказанные значения', color='blue')
plt.plot(y_test1[700:800], label='Реальные значения', color='red')
plt.title('Сравнение предсказанных и реальных значений')
plt.xlabel('Индекс')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Оценка MAE
mae = mean_absolute_error(y_test1, y_pred1)

# Оценка MSE
mse = mean_squared_error(y_test1, y_pred1)

# Оценка RMSE
rmse = np.sqrt(mse)

# Оценка R^2
r2 = r2_score(y_test1, y_pred1)

print("Средняя абсолютная ошибка (MAE):", mae)
print("Средняя квадратичная ошибка (MSE):", mse)
print("Корень из среднеквадратичной ошибки (RMSE):", rmse)
print("Коэффициент детерминации (R^2):", r2)
# Out:
# Средняя абсолютная ошибка (MAE): 0.41362002994297176
# Средняя квадратичная ошибка (MSE): 0.35830359359857117
# Корень из среднеквадратичной ошибки (RMSE): 0.5985846586729159
# Коэффициент детерминации (R^2): 0.8787204373261297
